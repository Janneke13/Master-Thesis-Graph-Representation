# %% [markdown]
# # Hyperparameter Optimization DMG777k Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read in data

# %% [markdown]
# ## GAE

# %%
# first, read in the data from the files:

# lr = 0.001, filtered
gae_lr1_s0_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_1/results.csv")
gae_lr1_s1_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_2/results.csv")
gae_lr1_s2_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_3/results.csv")

# lr = 0.005, filtered
gae_lr2_s0_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_4/results.csv")
gae_lr2_s1_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_5/results.csv")
gae_lr2_s2_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_6/results.csv")

# lr = 0.01, filtered
gae_lr3_s0_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_7/results.csv")
gae_lr3_s1_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_8/results.csv")
gae_lr3_s2_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_9/results.csv")

# lr = 0.1, filtered
gae_lr4_s0_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_10/results.csv")
gae_lr4_s1_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_11/results.csv")
gae_lr4_s2_filtered = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_12/results.csv")

# -----------------------------------

# lr = 0.001, all-to-one
gae_lr1_s0_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_1/results.csv")
gae_lr1_s1_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_2/results.csv")
gae_lr1_s2_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_3/results.csv")

# lr = 0.005, all-to-one
gae_lr2_s0_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_4/results.csv")
gae_lr2_s1_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_5/results.csv")
gae_lr2_s2_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_6/results.csv")

# lr = 0.01, all-to-one
gae_lr3_s0_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_7/results.csv")
gae_lr3_s1_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_8/results.csv")
gae_lr3_s2_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_9/results.csv")

# lr = 0.1, all-to-one
gae_lr4_s0_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_10/results.csv")
gae_lr4_s1_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_11/results.csv")
gae_lr4_s2_alltoone = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_12/results.csv")

# -----------------------------------
# lr = 0.001, collapsed
gae_lr1_s0_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_1/results.csv")
gae_lr1_s1_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_2/results.csv")
gae_lr1_s2_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_3/results.csv")

# lr = 0.005, collapsed
gae_lr2_s0_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_4/results.csv")
gae_lr2_s1_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_5/results.csv")
gae_lr2_s2_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_6/results.csv")

# lr = 0.01, collapsed
gae_lr3_s0_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_7/results.csv")
gae_lr3_s1_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_8/results.csv")
gae_lr3_s2_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_9/results.csv")

# lr = 0.1, collapsed
gae_lr4_s0_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_10/results.csv")
gae_lr4_s1_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_11/results.csv")
gae_lr4_s2_collapsed = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_12/results.csv")

# -----------------------------------
# lr = 0.001, separate
gae_lr1_s0_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_1/results.csv")
gae_lr1_s1_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_2/results.csv")
gae_lr1_s2_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_3/results.csv")

# lr = 0.005, separate
gae_lr2_s0_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_4/results.csv")
gae_lr2_s1_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_5/results.csv")
gae_lr2_s2_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_6/results.csv")

# lr = 0.01, separate
gae_lr3_s0_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_7/results.csv")
gae_lr3_s1_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_8/results.csv")
gae_lr3_s2_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_9/results.csv")

# lr = 0.1, separate
gae_lr4_s0_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_10/results.csv")
gae_lr4_s1_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_11/results.csv")
gae_lr4_s2_separate = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_12/results.csv")





# -------- FINAL RESULTS (clustering) ----
# first, read in the data from the files:

# lr = 0.001, filtered
gae_lr1_s0_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_1/final_results.csv")
gae_lr1_s1_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_2/final_results.csv")
gae_lr1_s2_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_3/final_results.csv")

# lr = 0.005, filtered
gae_lr2_s0_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_4/final_results.csv")
gae_lr2_s1_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_5/final_results.csv")
gae_lr2_s2_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_6/final_results.csv")

# lr = 0.01, filtered
gae_lr3_s0_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_7/final_results.csv")
gae_lr3_s1_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_8/final_results.csv")
gae_lr3_s2_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_9/final_results.csv")

# lr = 0.1, filtered
gae_lr4_s0_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_10/final_results.csv")
gae_lr4_s1_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_11/final_results.csv")
gae_lr4_s2_filtered_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_filtered/dmg777k_12/final_results.csv")

# -----------------------------------

# lr = 0.001, all-to-one
gae_lr1_s0_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_1/final_results.csv")
gae_lr1_s1_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_2/final_results.csv")
gae_lr1_s2_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_3/final_results.csv")

# lr = 0.005, all-to-one
gae_lr2_s0_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_4/final_results.csv")
gae_lr2_s1_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_5/final_results.csv")
gae_lr2_s2_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_6/final_results.csv")

# lr = 0.01, all-to-one
gae_lr3_s0_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_7/final_results.csv")
gae_lr3_s1_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_8/final_results.csv")
gae_lr3_s2_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_9/final_results.csv")

# lr = 0.1, all-to-one
gae_lr4_s0_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_10/final_results.csv")
gae_lr4_s1_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_11/final_results.csv")
gae_lr4_s2_alltoone_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_alltoone/dmg777k_12/final_results.csv")

# -----------------------------------
# lr = 0.001, collapsed
gae_lr1_s0_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_1/final_results.csv")
gae_lr1_s1_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_2/final_results.csv")
gae_lr1_s2_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_3/final_results.csv")

# lr = 0.005, collapsed
gae_lr2_s0_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_4/final_results.csv")
gae_lr2_s1_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_5/final_results.csv")
gae_lr2_s2_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_6/final_results.csv")

# lr = 0.01, collapsed
gae_lr3_s0_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_7/final_results.csv")
gae_lr3_s1_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_8/final_results.csv")
gae_lr3_s2_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_9/final_results.csv")

# lr = 0.1, collapsed
gae_lr4_s0_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_10/final_results.csv")
gae_lr4_s1_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_11/final_results.csv")
gae_lr4_s2_collapsed_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_collapsed/dmg777k_12/final_results.csv")

# -----------------------------------
# lr = 0.001, separate
gae_lr1_s0_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_1/final_results.csv")
gae_lr1_s1_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_2/final_results.csv")
gae_lr1_s2_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_3/final_results.csv")

# lr = 0.005, separate
gae_lr2_s0_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_4/final_results.csv")
gae_lr2_s1_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_5/final_results.csv")
gae_lr2_s2_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_6/final_results.csv")

# lr = 0.01, separate
gae_lr3_s0_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_7/final_results.csv")
gae_lr3_s1_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_8/final_results.csv")
gae_lr3_s2_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_9/final_results.csv")

# lr = 0.1, separate
gae_lr4_s0_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_10/final_results.csv")
gae_lr4_s1_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_11/final_results.csv")
gae_lr4_s2_separate_final = pd.read_csv("../results/GAE/validation_lr_dmg777k_separate/dmg777k_12/final_results.csv")

# %% [markdown]
# ## GCN

# %%
# first, read in the data from the files:

# lr = 0.001, filtered
gcn_lr1_s0_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__1/results.csv")
gcn_lr1_s1_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__2/results.csv")
gcn_lr1_s2_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__3/results.csv")

# lr = 0.005, filtered
gcn_lr2_s0_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__4/results.csv")
gcn_lr2_s1_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__5/results.csv")
gcn_lr2_s2_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__6/results.csv")

# lr = 0.01, filtered
gcn_lr3_s0_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__7/results.csv")
gcn_lr3_s1_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__8/results.csv")
gcn_lr3_s2_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__9/results.csv")

# lr = 0.1, filtered
gcn_lr4_s0_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__10/results.csv")
gcn_lr4_s1_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__11/results.csv")
gcn_lr4_s2_filtered = pd.read_csv("../results/GCN/validation_lr_dmg777k_filtered/dmg777k_valid__12/results.csv")

# -----------------------------------

# lr = 0.001, all-to-one
gcn_lr1_s0_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__1/results.csv")
gcn_lr1_s1_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__2/results.csv")
gcn_lr1_s2_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__3/results.csv")

# lr = 0.005, all-to-one
gcn_lr2_s0_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__4/results.csv")
gcn_lr2_s1_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__5/results.csv")
gcn_lr2_s2_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__6/results.csv")

# lr = 0.01, all-to-one
gcn_lr3_s0_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__7/results.csv")
gcn_lr3_s1_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__8/results.csv")
gcn_lr3_s2_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__9/results.csv")

# lr = 0.1, all-to-one
gcn_lr4_s0_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__10/results.csv")
gcn_lr4_s1_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__11/results.csv")
gcn_lr4_s2_alltoone = pd.read_csv("../results/GCN/validation_lr_dmg777k_alltoone/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, collapsed
gcn_lr1_s0_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__1/results.csv")
gcn_lr1_s1_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__2/results.csv")
gcn_lr1_s2_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__3/results.csv")

# lr = 0.005, collapsed
gcn_lr2_s0_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__4/results.csv")
gcn_lr2_s1_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__5/results.csv")
gcn_lr2_s2_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__6/results.csv")

# lr = 0.01, collapsed
gcn_lr3_s0_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__7/results.csv")
gcn_lr3_s1_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__8/results.csv")
gcn_lr3_s2_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__9/results.csv")

# lr = 0.1, collapsed
gcn_lr4_s0_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__10/results.csv")
gcn_lr4_s1_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__11/results.csv")
gcn_lr4_s2_collapsed = pd.read_csv("../results/GCN/validation_lr_dmg777k_collapsed/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, separate
gcn_lr1_s0_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__1/results.csv")
gcn_lr1_s1_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__2/results.csv")
gcn_lr1_s2_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__3/results.csv")

# lr = 0.005, separate
gcn_lr2_s0_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__4/results.csv")
gcn_lr2_s1_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__5/results.csv")
gcn_lr2_s2_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__6/results.csv")

# lr = 0.01, separate
gcn_lr3_s0_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__7/results.csv")
gcn_lr3_s1_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__8/results.csv")
gcn_lr3_s2_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__9/results.csv")

# lr = 0.1, separate
gcn_lr4_s0_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__10/results.csv")
gcn_lr4_s1_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__11/results.csv")
gcn_lr4_s2_separate = pd.read_csv("../results/GCN/validation_lr_dmg777k_separate/dmg777k_valid__12/results.csv")

# %% [markdown]
# ## R-GCN

# %%
# first, read in the data from the files:

# lr = 0.001, filtered
rgcn_lr1_s0_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__1/results.csv")
rgcn_lr1_s1_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__2/results.csv")
rgcn_lr1_s2_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__3/results.csv")

# lr = 0.005, filtered
rgcn_lr2_s0_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__4/results.csv")
rgcn_lr2_s1_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__5/results.csv")
rgcn_lr2_s2_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__6/results.csv")

# lr = 0.01, filtered
rgcn_lr3_s0_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__7/results.csv")
rgcn_lr3_s1_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__8/results.csv")
rgcn_lr3_s2_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__9/results.csv")

# lr = 0.1, filtered
rgcn_lr4_s0_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__10/results.csv")
rgcn_lr4_s1_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__11/results.csv")
rgcn_lr4_s2_filtered = pd.read_csv("../results/RGCN/validation_lr_dmg777k_filtered/dmg777k_valid__12/results.csv")

# -----------------------------------

# lr = 0.001, all-to-one
rgcn_lr1_s0_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__1/results.csv")
rgcn_lr1_s1_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__2/results.csv")
rgcn_lr1_s2_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__3/results.csv")

# lr = 0.005, all-to-one
rgcn_lr2_s0_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__4/results.csv")
rgcn_lr2_s1_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__5/results.csv")
rgcn_lr2_s2_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__6/results.csv")

# lr = 0.01, all-to-one
rgcn_lr3_s0_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__7/results.csv")
rgcn_lr3_s1_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__8/results.csv")
rgcn_lr3_s2_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__9/results.csv")

# lr = 0.1, all-to-one
rgcn_lr4_s0_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__10/results.csv")
rgcn_lr4_s1_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__11/results.csv")
rgcn_lr4_s2_alltoone = pd.read_csv("../results/RGCN/validation_lr_dmg777k_alltoone/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, collapsed
rgcn_lr1_s0_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__1/results.csv")
rgcn_lr1_s1_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__2/results.csv")
rgcn_lr1_s2_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__3/results.csv")

# lr = 0.005, collapsed
rgcn_lr2_s0_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__4/results.csv")
rgcn_lr2_s1_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__5/results.csv")
rgcn_lr2_s2_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__6/results.csv")

# lr = 0.01, collapsed
rgcn_lr3_s0_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__7/results.csv")
rgcn_lr3_s1_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__8/results.csv")
rgcn_lr3_s2_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__9/results.csv")

# lr = 0.1, collapsed
rgcn_lr4_s0_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__10/results.csv")
rgcn_lr4_s1_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__11/results.csv")
rgcn_lr4_s2_collapsed = pd.read_csv("../results/RGCN/validation_lr_dmg777k_collapsed/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, separate
rgcn_lr1_s0_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__1/results.csv")
rgcn_lr1_s1_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__2/results.csv")
rgcn_lr1_s2_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__3/results.csv")

# lr = 0.005, separate
rgcn_lr2_s0_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__4/results.csv")
rgcn_lr2_s1_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__5/results.csv")
rgcn_lr2_s2_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__6/results.csv")

# lr = 0.01, separate
rgcn_lr3_s0_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__7/results.csv")
rgcn_lr3_s1_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__8/results.csv")
rgcn_lr3_s2_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__9/results.csv")

# lr = 0.1, separate
rgcn_lr4_s0_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__10/results.csv")
rgcn_lr4_s1_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__11/results.csv")
rgcn_lr4_s2_separate = pd.read_csv("../results/RGCN/validation_lr_dmg777k_separate/dmg777k_valid__12/results.csv")

# %% [markdown]
# ## GAT

# %%
# first, read in the data from the files:

# lr = 0.001, filtered
gat_lr1_s0_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__1/results.csv")
gat_lr1_s1_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__2/results.csv")
gat_lr1_s2_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__3/results.csv")

# lr = 0.005, filtered
gat_lr2_s0_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__4/results.csv")
gat_lr2_s1_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__5/results.csv")
gat_lr2_s2_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__6/results.csv")

# lr = 0.01, filtered
gat_lr3_s0_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__7/results.csv")
gat_lr3_s1_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__8/results.csv")
gat_lr3_s2_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__9/results.csv")

# lr = 0.1, filtered
gat_lr4_s0_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__10/results.csv")
gat_lr4_s1_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__11/results.csv")
gat_lr4_s2_filtered = pd.read_csv("../results/GAT/validation_lr_dmg777k_filtered/dmg777k_valid__12/results.csv")

# -----------------------------------

# lr = 0.001, all-to-one
gat_lr1_s0_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__1/results.csv")
gat_lr1_s1_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__2/results.csv")
gat_lr1_s2_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__3/results.csv")

# lr = 0.005, all-to-one
gat_lr2_s0_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__4/results.csv")
gat_lr2_s1_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__5/results.csv")
gat_lr2_s2_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__6/results.csv")

# lr = 0.01, all-to-one
gat_lr3_s0_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__7/results.csv")
gat_lr3_s1_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__8/results.csv")
gat_lr3_s2_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__9/results.csv")

# lr = 0.1, all-to-one
gat_lr4_s0_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__10/results.csv")
gat_lr4_s1_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__11/results.csv")
gat_lr4_s2_alltoone = pd.read_csv("../results/GAT/validation_lr_dmg777k_alltoone/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, collapsed
gat_lr1_s0_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__1/results.csv")
gat_lr1_s1_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__2/results.csv")
gat_lr1_s2_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__3/results.csv")

# lr = 0.005, collapsed
gat_lr2_s0_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__4/results.csv")
gat_lr2_s1_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__5/results.csv")
gat_lr2_s2_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__6/results.csv")

# lr = 0.01, collapsed
gat_lr3_s0_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__7/results.csv")
gat_lr3_s1_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__8/results.csv")
gat_lr3_s2_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__9/results.csv")

# lr = 0.1, collapsed
gat_lr4_s0_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__10/results.csv")
gat_lr4_s1_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__11/results.csv")
gat_lr4_s2_collapsed = pd.read_csv("../results/GAT/validation_lr_dmg777k_collapsed/dmg777k_valid__12/results.csv")

# -----------------------------------
# lr = 0.001, separate
gat_lr1_s0_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__1/results.csv")
gat_lr1_s1_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__2/results.csv")
gat_lr1_s2_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__3/results.csv")

# lr = 0.005, separate
gat_lr2_s0_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__4/results.csv")
gat_lr2_s1_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__5/results.csv")
gat_lr2_s2_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__6/results.csv")

# lr = 0.01, separate
gat_lr3_s0_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__7/results.csv")
gat_lr3_s1_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__8/results.csv")
gat_lr3_s2_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__9/results.csv")

# lr = 0.1, separate
gat_lr4_s0_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__10/results.csv")
gat_lr4_s1_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__11/results.csv")
gat_lr4_s2_separate = pd.read_csv("../results/GAT/validation_lr_dmg777k_separate/dmg777k_valid__12/results.csv")

# %% [markdown]
# ## Create plots for learning rates:

# %% [markdown]
# ### Filtered:

# %%
# concatenate all these results

# ---- GAE ---- 
# only for the reconstruction loss
rec_loss_gae_lr1_filtered = pd.concat([gae_lr1_s0_filtered['ReconLossTrain'], gae_lr1_s1_filtered['ReconLossTrain'], gae_lr1_s2_filtered['ReconLossTrain']], axis=1)
rec_loss_gae_lr2_filtered = pd.concat([gae_lr2_s0_filtered['ReconLossTrain'], gae_lr2_s1_filtered['ReconLossTrain'], gae_lr2_s2_filtered['ReconLossTrain']], axis=1)
rec_loss_gae_lr3_filtered = pd.concat([gae_lr3_s0_filtered['ReconLossTrain'], gae_lr3_s1_filtered['ReconLossTrain'], gae_lr3_s2_filtered['ReconLossTrain']], axis=1)
rec_loss_gae_lr4_filtered = pd.concat([gae_lr4_s0_filtered['ReconLossTrain'], gae_lr4_s1_filtered['ReconLossTrain'], gae_lr4_s2_filtered['ReconLossTrain']], axis=1)

# ---- GCN ------
accuracy_all_gcn_lr1_filtered = pd.concat([gcn_lr1_s0_filtered['AccTest'], gcn_lr1_s1_filtered['AccTest'], gcn_lr1_s2_filtered['AccTest']], axis=1)
loss_all_gcn_lr1_filtered = pd.concat([gcn_lr1_s0_filtered['CrossEntropyLossTest'], gcn_lr1_s1_filtered['CrossEntropyLossTest'], gcn_lr1_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr2_filtered = pd.concat([gcn_lr2_s0_filtered['AccTest'], gcn_lr2_s1_filtered['AccTest'], gcn_lr2_s2_filtered['AccTest']], axis=1)
loss_all_gcn_lr2_filtered = pd.concat([gcn_lr2_s0_filtered['CrossEntropyLossTest'], gcn_lr2_s1_filtered['CrossEntropyLossTest'], gcn_lr2_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr3_filtered = pd.concat([gcn_lr3_s0_filtered['AccTest'], gcn_lr3_s1_filtered['AccTest'], gcn_lr3_s2_filtered['AccTest']], axis=1)
loss_all_gcn_lr3_filtered = pd.concat([gcn_lr3_s0_filtered['CrossEntropyLossTest'], gcn_lr3_s1_filtered['CrossEntropyLossTest'], gcn_lr3_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr4_filtered = pd.concat([gcn_lr4_s0_filtered['AccTest'], gcn_lr4_s1_filtered['AccTest'], gcn_lr4_s2_filtered['AccTest']], axis=1)
loss_all_gcn_lr4_filtered = pd.concat([gcn_lr4_s0_filtered['CrossEntropyLossTest'], gcn_lr4_s1_filtered['CrossEntropyLossTest'], gcn_lr4_s2_filtered['CrossEntropyLossTest']], axis=1)

# ---- RGCN ------
accuracy_all_rgcn_lr1_filtered = pd.concat([rgcn_lr1_s0_filtered['AccTest'], rgcn_lr1_s1_filtered['AccTest'], rgcn_lr1_s2_filtered['AccTest']], axis=1)
loss_all_rgcn_lr1_filtered = pd.concat([rgcn_lr1_s0_filtered['CrossEntropyLossTest'], rgcn_lr1_s1_filtered['CrossEntropyLossTest'], rgcn_lr1_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr2_filtered = pd.concat([rgcn_lr2_s0_filtered['AccTest'], rgcn_lr2_s1_filtered['AccTest'], rgcn_lr2_s2_filtered['AccTest']], axis=1)
loss_all_rgcn_lr2_filtered = pd.concat([rgcn_lr2_s0_filtered['CrossEntropyLossTest'], rgcn_lr2_s1_filtered['CrossEntropyLossTest'], rgcn_lr2_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr3_filtered = pd.concat([rgcn_lr3_s0_filtered['AccTest'], rgcn_lr3_s1_filtered['AccTest'], rgcn_lr3_s2_filtered['AccTest']], axis=1)
loss_all_rgcn_lr3_filtered = pd.concat([rgcn_lr3_s0_filtered['CrossEntropyLossTest'], rgcn_lr3_s1_filtered['CrossEntropyLossTest'], rgcn_lr3_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr4_filtered = pd.concat([rgcn_lr4_s0_filtered['AccTest'], rgcn_lr4_s1_filtered['AccTest'], rgcn_lr4_s2_filtered['AccTest']], axis=1)
loss_all_rgcn_lr4_filtered = pd.concat([rgcn_lr4_s0_filtered['CrossEntropyLossTest'], rgcn_lr4_s1_filtered['CrossEntropyLossTest'], rgcn_lr4_s2_filtered['CrossEntropyLossTest']], axis=1)

# ---- GAT ------
accuracy_all_gat_lr1_filtered = pd.concat([gat_lr1_s0_filtered['AccTest'], gat_lr1_s1_filtered['AccTest'], gat_lr1_s2_filtered['AccTest']], axis=1)
loss_all_gat_lr1_filtered = pd.concat([gat_lr1_s0_filtered['CrossEntropyLossTest'], gat_lr1_s1_filtered['CrossEntropyLossTest'], gat_lr1_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr2_filtered = pd.concat([gat_lr2_s0_filtered['AccTest'], gat_lr2_s1_filtered['AccTest'], gat_lr2_s2_filtered['AccTest']], axis=1)
loss_all_gat_lr2_filtered = pd.concat([gat_lr2_s0_filtered['CrossEntropyLossTest'], gat_lr2_s1_filtered['CrossEntropyLossTest'], gat_lr2_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr3_filtered = pd.concat([gat_lr3_s0_filtered['AccTest'], gat_lr3_s1_filtered['AccTest'], gat_lr3_s2_filtered['AccTest']], axis=1)
loss_all_gat_lr3_filtered = pd.concat([gat_lr3_s0_filtered['CrossEntropyLossTest'], gat_lr3_s1_filtered['CrossEntropyLossTest'], gat_lr3_s2_filtered['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr4_filtered = pd.concat([gat_lr4_s0_filtered['AccTest'], gat_lr4_s1_filtered['AccTest'], gat_lr4_s2_filtered['AccTest']], axis=1)
loss_all_gat_lr4_filtered = pd.concat([gat_lr4_s0_filtered['CrossEntropyLossTest'], gat_lr4_s1_filtered['CrossEntropyLossTest'], gat_lr4_s2_filtered['CrossEntropyLossTest']], axis=1)

# %%
# get the mean and std of all these results!
# GCN
mean_accuracy_all_gcn_lr1_filtered = accuracy_all_gcn_lr1_filtered.mean(axis=1)
std_accuracy_all_gcn_lr1_filtered = accuracy_all_gcn_lr1_filtered.std(axis=1)

mean_accuracy_all_gcn_lr2_filtered = accuracy_all_gcn_lr2_filtered.mean(axis=1)
std_accuracy_all_gcn_lr2_filtered = accuracy_all_gcn_lr2_filtered.std(axis=1)

mean_accuracy_all_gcn_lr3_filtered = accuracy_all_gcn_lr3_filtered.mean(axis=1)
std_accuracy_all_gcn_lr3_filtered = accuracy_all_gcn_lr3_filtered.std(axis=1)

mean_accuracy_all_gcn_lr4_filtered = accuracy_all_gcn_lr4_filtered.mean(axis=1)
std_accuracy_all_gcn_lr4_filtered = accuracy_all_gcn_lr4_filtered.std(axis=1)

# RGCN
mean_accuracy_all_rgcn_lr1_filtered = accuracy_all_rgcn_lr1_filtered.mean(axis=1)
std_accuracy_all_rgcn_lr1_filtered = accuracy_all_rgcn_lr1_filtered.std(axis=1)

mean_accuracy_all_rgcn_lr2_filtered = accuracy_all_rgcn_lr2_filtered.mean(axis=1)
std_accuracy_all_rgcn_lr2_filtered = accuracy_all_rgcn_lr2_filtered.std(axis=1)

mean_accuracy_all_rgcn_lr3_filtered = accuracy_all_rgcn_lr3_filtered.mean(axis=1)
std_accuracy_all_rgcn_lr3_filtered = accuracy_all_rgcn_lr3_filtered.std(axis=1)

mean_accuracy_all_rgcn_lr4_filtered = accuracy_all_rgcn_lr4_filtered.mean(axis=1)
std_accuracy_all_rgcn_lr4_filtered = accuracy_all_rgcn_lr4_filtered.std(axis=1)

# GAT
mean_accuracy_all_gat_lr1_filtered = accuracy_all_gat_lr1_filtered.mean(axis=1)
std_accuracy_all_gat_lr1_filtered = accuracy_all_gat_lr1_filtered.std(axis=1)

mean_accuracy_all_gat_lr2_filtered = accuracy_all_gat_lr2_filtered.mean(axis=1)
std_accuracy_all_gat_lr2_filtered = accuracy_all_gat_lr2_filtered.std(axis=1)

mean_accuracy_all_gat_lr3_filtered = accuracy_all_gat_lr3_filtered.mean(axis=1)
std_accuracy_all_gat_lr3_filtered = accuracy_all_gat_lr3_filtered.std(axis=1)

mean_accuracy_all_gat_lr4_filtered = accuracy_all_gat_lr4_filtered.mean(axis=1)
std_accuracy_all_gat_lr4_filtered = accuracy_all_gat_lr4_filtered.std(axis=1)

# %%
# GAE
mean_rec_loss_gae_lr1_filtered = rec_loss_gae_lr1_filtered.mean(axis=1)
std_rec_loss_gae_lr1_filtered = rec_loss_gae_lr1_filtered.std(axis=1)

mean_rec_loss_gae_lr2_filtered = rec_loss_gae_lr2_filtered.mean(axis=1)
std_rec_loss_gae_lr2_filtered = rec_loss_gae_lr2_filtered.std(axis=1)

mean_rec_loss_gae_lr3_filtered = rec_loss_gae_lr3_filtered.mean(axis=1)
std_rec_loss_gae_lr3_filtered = rec_loss_gae_lr3_filtered.std(axis=1)

mean_rec_loss_gae_lr4_filtered = rec_loss_gae_lr4_filtered.mean(axis=1)
std_rec_loss_gae_lr4_filtered = rec_loss_gae_lr4_filtered.std(axis=1)

# GCN
mean_loss_all_gcn_lr1_filtered = loss_all_gcn_lr1_filtered.mean(axis=1)
std_loss_all_gcn_lr1_filtered = loss_all_gcn_lr1_filtered.std(axis=1)

mean_loss_all_gcn_lr2_filtered = loss_all_gcn_lr2_filtered.mean(axis=1)
std_loss_all_gcn_lr2_filtered = loss_all_gcn_lr2_filtered.std(axis=1)

mean_loss_all_gcn_lr3_filtered = loss_all_gcn_lr3_filtered.mean(axis=1)
std_loss_all_gcn_lr3_filtered = loss_all_gcn_lr3_filtered.std(axis=1)

mean_loss_all_gcn_lr4_filtered = loss_all_gcn_lr4_filtered.mean(axis=1)
std_loss_all_gcn_lr4_filtered = loss_all_gcn_lr4_filtered.std(axis=1)

# RGCN
mean_loss_all_rgcn_lr1_filtered = loss_all_rgcn_lr1_filtered.mean(axis=1)
std_loss_all_rgcn_lr1_filtered = loss_all_rgcn_lr1_filtered.std(axis=1)

mean_loss_all_rgcn_lr2_filtered = loss_all_rgcn_lr2_filtered.mean(axis=1)
std_loss_all_rgcn_lr2_filtered = loss_all_rgcn_lr2_filtered.std(axis=1)

mean_loss_all_rgcn_lr3_filtered = loss_all_rgcn_lr3_filtered.mean(axis=1)
std_loss_all_rgcn_lr3_filtered = loss_all_rgcn_lr3_filtered.std(axis=1)

mean_loss_all_rgcn_lr4_filtered = loss_all_rgcn_lr4_filtered.mean(axis=1)
std_loss_all_rgcn_lr4_filtered = loss_all_rgcn_lr4_filtered.std(axis=1)

# GAT
mean_loss_all_gat_lr1_filtered = loss_all_gat_lr1_filtered.mean(axis=1)
std_loss_all_gat_lr1_filtered = loss_all_gat_lr1_filtered.std(axis=1)

mean_loss_all_gat_lr2_filtered = loss_all_gat_lr2_filtered.mean(axis=1)
std_loss_all_gat_lr2_filtered = loss_all_gat_lr2_filtered.std(axis=1)

mean_loss_all_gat_lr3_filtered = loss_all_gat_lr3_filtered.mean(axis=1)
std_loss_all_gat_lr3_filtered = loss_all_gat_lr3_filtered.std(axis=1)

mean_loss_all_gat_lr4_filtered = loss_all_gat_lr4_filtered.mean(axis=1)
std_loss_all_gat_lr4_filtered = loss_all_gat_lr4_filtered.std(axis=1)

# %% [markdown]
# Create the plots! LR 1 is 0.001, LR2 is 0.005, LR3 is 0.01, LR4 is 0.1

# %%
# draw the lines for the means
plt.plot(mean_rec_loss_gae_lr1_filtered.index.values, mean_rec_loss_gae_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_rec_loss_gae_lr2_filtered.index.values, mean_rec_loss_gae_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_rec_loss_gae_lr3_filtered.index.values, mean_rec_loss_gae_lr3_filtered, 'b-', label='Learning Rate: 0.01')
#plt.plot(mean_rec_loss_gae_lr4_filtered.index.values, mean_rec_loss_gae_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_rec_loss_gae_lr1_filtered.index.values, mean_rec_loss_gae_lr1_filtered - std_rec_loss_gae_lr1_filtered, mean_rec_loss_gae_lr1_filtered + std_rec_loss_gae_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr2_filtered.index.values, mean_rec_loss_gae_lr2_filtered - std_rec_loss_gae_lr2_filtered, mean_rec_loss_gae_lr2_filtered + std_rec_loss_gae_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr3_filtered.index.values, mean_rec_loss_gae_lr3_filtered - std_rec_loss_gae_lr3_filtered, mean_rec_loss_gae_lr3_filtered + std_rec_loss_gae_lr3_filtered, color='b', alpha=0.25)
#plt.fill_between(std_rec_loss_gae_lr4_filtered.index.values, mean_rec_loss_gae_lr4_filtered - std_rec_loss_gae_lr4_filtered, mean_rec_loss_gae_lr4_filtered + std_rec_loss_gae_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Reconstruction Loss of GAE for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Reconstruction Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gae_filtered_rec_loss.png', dpi=300)

plt.show()

# %%
from statistics import mean 
from statistics import stdev as std

# adj rand
gae_lr1_filtered_adj_rand_mean = mean([gae_lr1_s0_filtered_final['Rand12'][0], gae_lr1_s0_filtered_final['Rand23'][0], gae_lr1_s0_filtered_final['Rand13'][0], gae_lr1_s1_filtered_final['Rand12'][0], gae_lr1_s1_filtered_final['Rand23'][0], gae_lr1_s1_filtered_final['Rand13'][0], gae_lr1_s2_filtered_final['Rand12'][0], gae_lr1_s2_filtered_final['Rand23'][0], gae_lr1_s2_filtered_final['Rand13'][0]])
gae_lr1_filtered_adj_rand_std = std([gae_lr1_s0_filtered_final['Rand12'][0], gae_lr1_s0_filtered_final['Rand23'][0], gae_lr1_s0_filtered_final['Rand13'][0], gae_lr1_s1_filtered_final['Rand12'][0], gae_lr1_s1_filtered_final['Rand23'][0], gae_lr1_s1_filtered_final['Rand13'][0], gae_lr1_s2_filtered_final['Rand12'][0], gae_lr1_s2_filtered_final['Rand23'][0], gae_lr1_s2_filtered_final['Rand13'][0]])

gae_lr2_filtered_adj_rand_mean = mean([gae_lr2_s0_filtered_final['Rand12'][0], gae_lr2_s0_filtered_final['Rand23'][0], gae_lr2_s0_filtered_final['Rand13'][0], gae_lr2_s1_filtered_final['Rand12'][0], gae_lr2_s1_filtered_final['Rand23'][0], gae_lr2_s1_filtered_final['Rand13'][0], gae_lr2_s2_filtered_final['Rand12'][0], gae_lr2_s2_filtered_final['Rand23'][0], gae_lr2_s2_filtered_final['Rand13'][0]])
gae_lr2_filtered_adj_rand_std = std([gae_lr2_s0_filtered_final['Rand12'][0], gae_lr2_s0_filtered_final['Rand23'][0], gae_lr2_s0_filtered_final['Rand13'][0], gae_lr2_s1_filtered_final['Rand12'][0], gae_lr2_s1_filtered_final['Rand23'][0], gae_lr2_s1_filtered_final['Rand13'][0], gae_lr2_s2_filtered_final['Rand12'][0], gae_lr2_s2_filtered_final['Rand23'][0], gae_lr2_s2_filtered_final['Rand13'][0]])

gae_lr3_filtered_adj_rand_mean = mean([gae_lr3_s0_filtered_final['Rand12'][0], gae_lr3_s0_filtered_final['Rand23'][0], gae_lr3_s0_filtered_final['Rand13'][0], gae_lr3_s1_filtered_final['Rand12'][0], gae_lr3_s1_filtered_final['Rand23'][0], gae_lr3_s1_filtered_final['Rand13'][0], gae_lr3_s2_filtered_final['Rand12'][0], gae_lr3_s2_filtered_final['Rand23'][0], gae_lr3_s2_filtered_final['Rand13'][0]])
gae_lr3_filtered_adj_rand_std = std([gae_lr3_s0_filtered_final['Rand12'][0], gae_lr3_s0_filtered_final['Rand23'][0], gae_lr3_s0_filtered_final['Rand13'][0], gae_lr3_s1_filtered_final['Rand12'][0], gae_lr3_s1_filtered_final['Rand23'][0], gae_lr3_s1_filtered_final['Rand13'][0], gae_lr3_s2_filtered_final['Rand12'][0], gae_lr3_s2_filtered_final['Rand23'][0], gae_lr3_s2_filtered_final['Rand13'][0]])

gae_lr4_filtered_adj_rand_mean = mean([gae_lr4_s0_filtered_final['Rand12'][0], gae_lr4_s0_filtered_final['Rand23'][0], gae_lr4_s0_filtered_final['Rand13'][0], gae_lr4_s1_filtered_final['Rand12'][0], gae_lr4_s1_filtered_final['Rand23'][0], gae_lr4_s1_filtered_final['Rand13'][0], gae_lr4_s2_filtered_final['Rand12'][0], gae_lr4_s2_filtered_final['Rand23'][0], gae_lr4_s2_filtered_final['Rand13'][0]])
gae_lr4_filtered_adj_rand_std = std([gae_lr4_s0_filtered_final['Rand12'][0], gae_lr4_s0_filtered_final['Rand23'][0], gae_lr4_s0_filtered_final['Rand13'][0], gae_lr4_s1_filtered_final['Rand12'][0], gae_lr4_s1_filtered_final['Rand23'][0], gae_lr4_s1_filtered_final['Rand13'][0], gae_lr4_s2_filtered_final['Rand12'][0], gae_lr4_s2_filtered_final['Rand23'][0], gae_lr4_s2_filtered_final['Rand13'][0]])

# bic score
gae_lr1_filtered_bic_mean = mean([gae_lr1_s0_filtered_final['BIC_1'][0], gae_lr1_s0_filtered_final['BIC_2'][0], gae_lr1_s0_filtered_final['BIC_3'][0], gae_lr1_s1_filtered_final['BIC_1'][0], gae_lr1_s1_filtered_final['BIC_2'][0], gae_lr1_s1_filtered_final['BIC_3'][0], gae_lr1_s2_filtered_final['BIC_1'][0], gae_lr1_s2_filtered_final['BIC_2'][0], gae_lr1_s2_filtered_final['BIC_3'][0]])
gae_lr1_filtered_bic_std = std([gae_lr1_s0_filtered_final['BIC_1'][0], gae_lr1_s0_filtered_final['BIC_2'][0], gae_lr1_s0_filtered_final['BIC_3'][0], gae_lr1_s1_filtered_final['BIC_1'][0], gae_lr1_s1_filtered_final['BIC_2'][0], gae_lr1_s1_filtered_final['BIC_3'][0], gae_lr1_s2_filtered_final['BIC_1'][0], gae_lr1_s2_filtered_final['BIC_2'][0], gae_lr1_s2_filtered_final['BIC_3'][0]])

gae_lr2_filtered_bic_mean = mean([gae_lr2_s0_filtered_final['BIC_1'][0], gae_lr2_s0_filtered_final['BIC_2'][0], gae_lr2_s0_filtered_final['BIC_3'][0], gae_lr2_s1_filtered_final['BIC_1'][0], gae_lr2_s1_filtered_final['BIC_2'][0], gae_lr2_s1_filtered_final['BIC_3'][0], gae_lr2_s2_filtered_final['BIC_1'][0], gae_lr2_s2_filtered_final['BIC_2'][0], gae_lr2_s2_filtered_final['BIC_3'][0]])
gae_lr2_filtered_bic_std = std([gae_lr2_s0_filtered_final['BIC_1'][0], gae_lr2_s0_filtered_final['BIC_2'][0], gae_lr2_s0_filtered_final['BIC_3'][0], gae_lr2_s1_filtered_final['BIC_1'][0], gae_lr2_s1_filtered_final['BIC_2'][0], gae_lr2_s1_filtered_final['BIC_3'][0], gae_lr2_s2_filtered_final['BIC_1'][0], gae_lr2_s2_filtered_final['BIC_2'][0], gae_lr2_s2_filtered_final['BIC_3'][0]])

gae_lr3_filtered_bic_mean = mean([gae_lr3_s0_filtered_final['BIC_1'][0], gae_lr3_s0_filtered_final['BIC_2'][0], gae_lr3_s0_filtered_final['BIC_3'][0], gae_lr3_s1_filtered_final['BIC_1'][0], gae_lr3_s1_filtered_final['BIC_2'][0], gae_lr3_s1_filtered_final['BIC_3'][0], gae_lr3_s2_filtered_final['BIC_1'][0], gae_lr3_s2_filtered_final['BIC_2'][0], gae_lr3_s2_filtered_final['BIC_3'][0]])
gae_lr3_filtered_bic_std = std([gae_lr3_s0_filtered_final['BIC_1'][0], gae_lr3_s0_filtered_final['BIC_2'][0], gae_lr3_s0_filtered_final['BIC_3'][0], gae_lr3_s1_filtered_final['BIC_1'][0], gae_lr3_s1_filtered_final['BIC_2'][0], gae_lr3_s1_filtered_final['BIC_3'][0], gae_lr3_s2_filtered_final['BIC_1'][0], gae_lr3_s2_filtered_final['BIC_2'][0], gae_lr3_s2_filtered_final['BIC_3'][0]])
[0]
gae_lr4_filtered_bic_mean = mean([gae_lr4_s0_filtered_final['BIC_1'][0], gae_lr4_s0_filtered_final['BIC_2'][0], gae_lr4_s0_filtered_final['BIC_3'][0], gae_lr4_s1_filtered_final['BIC_1'][0], gae_lr4_s1_filtered_final['BIC_2'][0], gae_lr4_s1_filtered_final['BIC_3'][0], gae_lr4_s2_filtered_final['BIC_1'][0], gae_lr4_s2_filtered_final['BIC_2'][0], gae_lr4_s2_filtered_final['BIC_3'][0]])
gae_lr4_filtered_bic_std = std([gae_lr4_s0_filtered_final['BIC_1'][0], gae_lr4_s0_filtered_final['BIC_2'][0], gae_lr4_s0_filtered_final['BIC_3'][0], gae_lr4_s1_filtered_final['BIC_1'][0], gae_lr4_s1_filtered_final['BIC_2'][0], gae_lr4_s1_filtered_final['BIC_3'][0], gae_lr4_s2_filtered_final['BIC_1'][0], gae_lr4_s2_filtered_final['BIC_2'][0], gae_lr4_s2_filtered_final['BIC_3'][0]])

# print results
print("Learning rate 0.001: Adj. Rand. Mean: ",gae_lr1_filtered_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr1_filtered_adj_rand_std, ", BIC Mean: ", gae_lr1_filtered_bic_mean, ", BIC Std: ", gae_lr1_filtered_bic_std)
print("Learning rate 0.005: Adj. Rand. Mean: ",gae_lr2_filtered_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr2_filtered_adj_rand_std, ", BIC Mean: ", gae_lr2_filtered_bic_mean, ", BIC Std: ", gae_lr2_filtered_bic_std)
print("Learning rate 0.01: Adj. Rand. Mean: ",gae_lr3_filtered_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr3_filtered_adj_rand_std, ", BIC Mean: ", gae_lr3_filtered_bic_mean, ", BIC Std: ", gae_lr3_filtered_bic_std)
print("Learning rate 0.1: Adj. Rand. Mean: ",gae_lr4_filtered_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr4_filtered_adj_rand_std, ", BIC Mean: ", gae_lr4_filtered_bic_mean, ", BIC Std: ", gae_lr4_filtered_bic_std)
# Out:
# Learning rate 0.001: Adj. Rand. Mean:  0.6578631583846918 , Adj. Rand. Std.:  0.25515322460955003 , BIC Mean:  -521.7277955185136 , BIC Std:  13441.093514272912
# Learning rate 0.005: Adj. Rand. Mean:  0.5244994575541659 , Adj. Rand. Std.:  0.27347986227222815 , BIC Mean:  -11340.962056687711 , BIC Std:  25781.740495679016
# Learning rate 0.01: Adj. Rand. Mean:  0.42626974035763154 , Adj. Rand. Std.:  0.43698368537431714 , BIC Mean:  -918790.0878902605 , BIC Std:  790953.1837894939
# Learning rate 0.1: Adj. Rand. Mean:  0.7883857277414911 , Adj. Rand. Std.:  0.40393368718536055 , BIC Mean:  1346032.632721962 , BIC Std:  296431.5763468704

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gcn_lr1_filtered.index.values, mean_accuracy_all_gcn_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gcn_lr2_filtered.index.values, mean_accuracy_all_gcn_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gcn_lr3_filtered.index.values, mean_accuracy_all_gcn_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gcn_lr4_filtered.index.values, mean_accuracy_all_gcn_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gcn_lr1_filtered.index.values, mean_accuracy_all_gcn_lr1_filtered - std_accuracy_all_gcn_lr1_filtered, mean_accuracy_all_gcn_lr1_filtered + std_accuracy_all_gcn_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr2_filtered.index.values, mean_accuracy_all_gcn_lr2_filtered - std_accuracy_all_gcn_lr2_filtered, mean_accuracy_all_gcn_lr2_filtered + std_accuracy_all_gcn_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr3_filtered.index.values, mean_accuracy_all_gcn_lr3_filtered - std_accuracy_all_gcn_lr3_filtered, mean_accuracy_all_gcn_lr3_filtered + std_accuracy_all_gcn_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr4_filtered.index.values, mean_accuracy_all_gcn_lr4_filtered - std_accuracy_all_gcn_lr4_filtered, mean_accuracy_all_gcn_lr4_filtered + std_accuracy_all_gcn_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GCN for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_filtered_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gcn_lr1_filtered.index.values, mean_loss_all_gcn_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gcn_lr2_filtered.index.values, mean_loss_all_gcn_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gcn_lr3_filtered.index.values, mean_loss_all_gcn_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gcn_lr4_filtered.index.values, mean_loss_all_gcn_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gcn_lr1_filtered.index.values, mean_loss_all_gcn_lr1_filtered - std_loss_all_gcn_lr1_filtered, mean_loss_all_gcn_lr1_filtered + std_loss_all_gcn_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr2_filtered.index.values, mean_loss_all_gcn_lr2_filtered - std_loss_all_gcn_lr2_filtered, mean_loss_all_gcn_lr2_filtered + std_loss_all_gcn_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr3_filtered.index.values, mean_loss_all_gcn_lr3_filtered - std_loss_all_gcn_lr3_filtered, mean_loss_all_gcn_lr3_filtered + std_loss_all_gcn_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr4_filtered.index.values, mean_loss_all_gcn_lr4_filtered - std_loss_all_gcn_lr4_filtered, mean_loss_all_gcn_lr4_filtered + std_loss_all_gcn_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GCN for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_filtered_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_rgcn_lr1_filtered.index.values, mean_accuracy_all_rgcn_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_rgcn_lr2_filtered.index.values, mean_accuracy_all_rgcn_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_rgcn_lr3_filtered.index.values, mean_accuracy_all_rgcn_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_rgcn_lr4_filtered.index.values, mean_accuracy_all_rgcn_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_rgcn_lr1_filtered.index.values, mean_accuracy_all_rgcn_lr1_filtered - std_accuracy_all_rgcn_lr1_filtered, mean_accuracy_all_rgcn_lr1_filtered + std_accuracy_all_rgcn_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr2_filtered.index.values, mean_accuracy_all_rgcn_lr2_filtered - std_accuracy_all_rgcn_lr2_filtered, mean_accuracy_all_rgcn_lr2_filtered + std_accuracy_all_rgcn_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr3_filtered.index.values, mean_accuracy_all_rgcn_lr3_filtered - std_accuracy_all_rgcn_lr3_filtered, mean_accuracy_all_rgcn_lr3_filtered + std_accuracy_all_rgcn_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr4_filtered.index.values, mean_accuracy_all_rgcn_lr4_filtered - std_accuracy_all_rgcn_lr4_filtered, mean_accuracy_all_rgcn_lr4_filtered + std_accuracy_all_rgcn_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of R-GCN for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_filtered_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_rgcn_lr1_filtered.index.values, mean_loss_all_rgcn_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_rgcn_lr2_filtered.index.values, mean_loss_all_rgcn_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_rgcn_lr3_filtered.index.values, mean_loss_all_rgcn_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_rgcn_lr4_filtered.index.values, mean_loss_all_rgcn_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_rgcn_lr1_filtered.index.values, mean_loss_all_rgcn_lr1_filtered - std_loss_all_rgcn_lr1_filtered, mean_loss_all_rgcn_lr1_filtered + std_loss_all_rgcn_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr2_filtered.index.values, mean_loss_all_rgcn_lr2_filtered - std_loss_all_rgcn_lr2_filtered, mean_loss_all_rgcn_lr2_filtered + std_loss_all_rgcn_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr3_filtered.index.values, mean_loss_all_rgcn_lr3_filtered - std_loss_all_rgcn_lr3_filtered, mean_loss_all_rgcn_lr3_filtered + std_loss_all_rgcn_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr4_filtered.index.values, mean_loss_all_rgcn_lr4_filtered - std_loss_all_rgcn_lr4_filtered, mean_loss_all_rgcn_lr4_filtered + std_loss_all_rgcn_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of R-GCN for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_filtered_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gat_lr1_filtered.index.values, mean_accuracy_all_gat_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gat_lr2_filtered.index.values, mean_accuracy_all_gat_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gat_lr3_filtered.index.values, mean_accuracy_all_gat_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gat_lr4_filtered.index.values, mean_accuracy_all_gat_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gat_lr1_filtered.index.values, mean_accuracy_all_gat_lr1_filtered - std_accuracy_all_gat_lr1_filtered, mean_accuracy_all_gat_lr1_filtered + std_accuracy_all_gat_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr2_filtered.index.values, mean_accuracy_all_gat_lr2_filtered - std_accuracy_all_gat_lr2_filtered, mean_accuracy_all_gat_lr2_filtered + std_accuracy_all_gat_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr3_filtered.index.values, mean_accuracy_all_gat_lr3_filtered - std_accuracy_all_gat_lr3_filtered, mean_accuracy_all_gat_lr3_filtered + std_accuracy_all_gat_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr4_filtered.index.values, mean_accuracy_all_gat_lr4_filtered - std_accuracy_all_gat_lr4_filtered, mean_accuracy_all_gat_lr4_filtered + std_accuracy_all_gat_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GAT for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_filtered_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gat_lr1_filtered.index.values, mean_loss_all_gat_lr1_filtered, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gat_lr2_filtered.index.values, mean_loss_all_gat_lr2_filtered, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gat_lr3_filtered.index.values, mean_loss_all_gat_lr3_filtered, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gat_lr4_filtered.index.values, mean_loss_all_gat_lr4_filtered, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gat_lr1_filtered.index.values, mean_loss_all_gat_lr1_filtered - std_loss_all_gat_lr1_filtered, mean_loss_all_gat_lr1_filtered + std_loss_all_gat_lr1_filtered, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr2_filtered.index.values, mean_loss_all_gat_lr2_filtered - std_loss_all_gat_lr2_filtered, mean_loss_all_gat_lr2_filtered + std_loss_all_gat_lr2_filtered, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr3_filtered.index.values, mean_loss_all_gat_lr3_filtered - std_loss_all_gat_lr3_filtered, mean_loss_all_gat_lr3_filtered + std_loss_all_gat_lr3_filtered, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr4_filtered.index.values, mean_loss_all_gat_lr4_filtered - std_loss_all_gat_lr4_filtered, mean_loss_all_gat_lr4_filtered + std_loss_all_gat_lr4_filtered, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GAT for Filtered DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_filtered_valloss.png', dpi=300)

plt.show()

# %% [markdown]
# ### All-to-one:

# %%
# concatenate all these results
# only for the reconstruction loss (no wd used here)
rec_loss_gae_lr1_alltoone = pd.concat([gae_lr1_s0_alltoone['ReconLossTrain'], gae_lr1_s1_alltoone['ReconLossTrain'], gae_lr1_s2_alltoone['ReconLossTrain']], axis=1)
rec_loss_gae_lr2_alltoone = pd.concat([gae_lr2_s0_alltoone['ReconLossTrain'], gae_lr2_s1_alltoone['ReconLossTrain'], gae_lr2_s2_alltoone['ReconLossTrain']], axis=1)
rec_loss_gae_lr3_alltoone = pd.concat([gae_lr3_s0_alltoone['ReconLossTrain'], gae_lr3_s1_alltoone['ReconLossTrain'], gae_lr3_s2_alltoone['ReconLossTrain']], axis=1)
rec_loss_gae_lr4_alltoone = pd.concat([gae_lr4_s0_alltoone['ReconLossTrain'], gae_lr4_s1_alltoone['ReconLossTrain'], gae_lr4_s2_alltoone['ReconLossTrain']], axis=1)

# ---- GCN ------
accuracy_all_gcn_lr1_alltoone = pd.concat([gcn_lr1_s0_alltoone['AccTest'], gcn_lr1_s1_alltoone['AccTest'], gcn_lr1_s2_alltoone['AccTest']], axis=1)
loss_all_gcn_lr1_alltoone = pd.concat([gcn_lr1_s0_alltoone['CrossEntropyLossTest'], gcn_lr1_s1_alltoone['CrossEntropyLossTest'], gcn_lr1_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr2_alltoone = pd.concat([gcn_lr2_s0_alltoone['AccTest'], gcn_lr2_s1_alltoone['AccTest'], gcn_lr2_s2_alltoone['AccTest']], axis=1)
loss_all_gcn_lr2_alltoone = pd.concat([gcn_lr2_s0_alltoone['CrossEntropyLossTest'], gcn_lr2_s1_alltoone['CrossEntropyLossTest'], gcn_lr2_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr3_alltoone = pd.concat([gcn_lr3_s0_alltoone['AccTest'], gcn_lr3_s1_alltoone['AccTest'], gcn_lr3_s2_alltoone['AccTest']], axis=1)
loss_all_gcn_lr3_alltoone = pd.concat([gcn_lr3_s0_alltoone['CrossEntropyLossTest'], gcn_lr3_s1_alltoone['CrossEntropyLossTest'], gcn_lr3_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr4_alltoone = pd.concat([gcn_lr4_s0_alltoone['AccTest'], gcn_lr4_s1_alltoone['AccTest'], gcn_lr4_s2_alltoone['AccTest']], axis=1)
loss_all_gcn_lr4_alltoone = pd.concat([gcn_lr4_s0_alltoone['CrossEntropyLossTest'], gcn_lr4_s1_alltoone['CrossEntropyLossTest'], gcn_lr4_s2_alltoone['CrossEntropyLossTest']], axis=1)

# ---- RGCN ------
accuracy_all_rgcn_lr1_alltoone = pd.concat([rgcn_lr1_s0_alltoone['AccTest'], rgcn_lr1_s1_alltoone['AccTest'], rgcn_lr1_s2_alltoone['AccTest']], axis=1)
loss_all_rgcn_lr1_alltoone = pd.concat([rgcn_lr1_s0_alltoone['CrossEntropyLossTest'], rgcn_lr1_s1_alltoone['CrossEntropyLossTest'], rgcn_lr1_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr2_alltoone = pd.concat([rgcn_lr2_s0_alltoone['AccTest'], rgcn_lr2_s1_alltoone['AccTest'], rgcn_lr2_s2_alltoone['AccTest']], axis=1)
loss_all_rgcn_lr2_alltoone = pd.concat([rgcn_lr2_s0_alltoone['CrossEntropyLossTest'], rgcn_lr2_s1_alltoone['CrossEntropyLossTest'], rgcn_lr2_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr3_alltoone = pd.concat([rgcn_lr3_s0_alltoone['AccTest'], rgcn_lr3_s1_alltoone['AccTest'], rgcn_lr3_s2_alltoone['AccTest']], axis=1)
loss_all_rgcn_lr3_alltoone = pd.concat([rgcn_lr3_s0_alltoone['CrossEntropyLossTest'], rgcn_lr3_s1_alltoone['CrossEntropyLossTest'], rgcn_lr3_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr4_alltoone = pd.concat([rgcn_lr4_s0_alltoone['AccTest'], rgcn_lr4_s1_alltoone['AccTest'], rgcn_lr4_s2_alltoone['AccTest']], axis=1)
loss_all_rgcn_lr4_alltoone = pd.concat([rgcn_lr4_s0_alltoone['CrossEntropyLossTest'], rgcn_lr4_s1_alltoone['CrossEntropyLossTest'], rgcn_lr4_s2_alltoone['CrossEntropyLossTest']], axis=1)

# ---- GAT ------
accuracy_all_gat_lr1_alltoone = pd.concat([gat_lr1_s0_alltoone['AccTest'], gat_lr1_s1_alltoone['AccTest'], gat_lr1_s2_alltoone['AccTest']], axis=1)
loss_all_gat_lr1_alltoone = pd.concat([gat_lr1_s0_alltoone['CrossEntropyLossTest'], gat_lr1_s1_alltoone['CrossEntropyLossTest'], gat_lr1_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr2_alltoone = pd.concat([gat_lr2_s0_alltoone['AccTest'], gat_lr2_s1_alltoone['AccTest'], gat_lr2_s2_alltoone['AccTest']], axis=1)
loss_all_gat_lr2_alltoone = pd.concat([gat_lr2_s0_alltoone['CrossEntropyLossTest'], gat_lr2_s1_alltoone['CrossEntropyLossTest'], gat_lr2_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr3_alltoone = pd.concat([gat_lr3_s0_alltoone['AccTest'], gat_lr3_s1_alltoone['AccTest'], gat_lr3_s2_alltoone['AccTest']], axis=1)
loss_all_gat_lr3_alltoone = pd.concat([gat_lr3_s0_alltoone['CrossEntropyLossTest'], gat_lr3_s1_alltoone['CrossEntropyLossTest'], gat_lr3_s2_alltoone['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr4_alltoone = pd.concat([gat_lr4_s0_alltoone['AccTest'], gat_lr4_s1_alltoone['AccTest'], gat_lr4_s2_alltoone['AccTest']], axis=1)
loss_all_gat_lr4_alltoone = pd.concat([gat_lr4_s0_alltoone['CrossEntropyLossTest'], gat_lr4_s1_alltoone['CrossEntropyLossTest'], gat_lr4_s2_alltoone['CrossEntropyLossTest']], axis=1)

# %%
# get the mean and std of all these results!
# GCN
mean_accuracy_all_gcn_lr1_alltoone = accuracy_all_gcn_lr1_alltoone.mean(axis=1)
std_accuracy_all_gcn_lr1_alltoone = accuracy_all_gcn_lr1_alltoone.std(axis=1)

mean_accuracy_all_gcn_lr2_alltoone = accuracy_all_gcn_lr2_alltoone.mean(axis=1)
std_accuracy_all_gcn_lr2_alltoone= accuracy_all_gcn_lr2_alltoone.std(axis=1)

mean_accuracy_all_gcn_lr3_alltoone = accuracy_all_gcn_lr3_alltoone.mean(axis=1)
std_accuracy_all_gcn_lr3_alltoone = accuracy_all_gcn_lr3_alltoone.std(axis=1)

mean_accuracy_all_gcn_lr4_alltoone = accuracy_all_gcn_lr4_alltoone.mean(axis=1)
std_accuracy_all_gcn_lr4_alltoone = accuracy_all_gcn_lr4_alltoone.std(axis=1)

# RGCN
mean_accuracy_all_rgcn_lr1_alltoone = accuracy_all_rgcn_lr1_alltoone.mean(axis=1)
std_accuracy_all_rgcn_lr1_alltoone = accuracy_all_rgcn_lr1_alltoone.std(axis=1)

mean_accuracy_all_rgcn_lr2_alltoone = accuracy_all_rgcn_lr2_alltoone.mean(axis=1)
std_accuracy_all_rgcn_lr2_alltoone = accuracy_all_rgcn_lr2_alltoone.std(axis=1)

mean_accuracy_all_rgcn_lr3_alltoone = accuracy_all_rgcn_lr3_alltoone.mean(axis=1)
std_accuracy_all_rgcn_lr3_alltoone = accuracy_all_rgcn_lr3_alltoone.std(axis=1)

mean_accuracy_all_rgcn_lr4_alltoone = accuracy_all_rgcn_lr4_alltoone.mean(axis=1)
std_accuracy_all_rgcn_lr4_alltoone = accuracy_all_rgcn_lr4_alltoone.std(axis=1)

# GAT
mean_accuracy_all_gat_lr1_alltoone = accuracy_all_gat_lr1_alltoone.mean(axis=1)
std_accuracy_all_gat_lr1_alltoone = accuracy_all_gat_lr1_alltoone.std(axis=1)

mean_accuracy_all_gat_lr2_alltoone = accuracy_all_gat_lr2_alltoone.mean(axis=1)
std_accuracy_all_gat_lr2_alltoone = accuracy_all_gat_lr2_alltoone.std(axis=1)

mean_accuracy_all_gat_lr3_alltoone = accuracy_all_gat_lr3_alltoone.mean(axis=1)
std_accuracy_all_gat_lr3_alltoone = accuracy_all_gat_lr3_alltoone.std(axis=1)

mean_accuracy_all_gat_lr4_alltoone = accuracy_all_gat_lr4_alltoone.mean(axis=1)
std_accuracy_all_gat_lr4_alltoone = accuracy_all_gat_lr4_alltoone.std(axis=1)

# %%
# GAE
mean_rec_loss_gae_lr1_alltoone = rec_loss_gae_lr1_alltoone.mean(axis=1)
std_rec_loss_gae_lr1_alltoone = rec_loss_gae_lr1_alltoone.std(axis=1)

mean_rec_loss_gae_lr2_alltoone = rec_loss_gae_lr2_alltoone.mean(axis=1)
std_rec_loss_gae_lr2_alltoone = rec_loss_gae_lr2_alltoone.std(axis=1)

mean_rec_loss_gae_lr3_alltoone = rec_loss_gae_lr3_alltoone.mean(axis=1)
std_rec_loss_gae_lr3_alltoone = rec_loss_gae_lr3_alltoone.std(axis=1)

mean_rec_loss_gae_lr4_alltoone = rec_loss_gae_lr4_alltoone.mean(axis=1)
std_rec_loss_gae_lr4_alltoone = rec_loss_gae_lr4_alltoone.std(axis=1)

# GCN
mean_loss_all_gcn_lr1_alltoone = loss_all_gcn_lr1_alltoone.mean(axis=1)
std_loss_all_gcn_lr1_alltoone = loss_all_gcn_lr1_alltoone.std(axis=1)

mean_loss_all_gcn_lr2_alltoone = loss_all_gcn_lr2_alltoone.mean(axis=1)
std_loss_all_gcn_lr2_alltoone = loss_all_gcn_lr2_alltoone.std(axis=1)

mean_loss_all_gcn_lr3_alltoone = loss_all_gcn_lr3_alltoone.mean(axis=1)
std_loss_all_gcn_lr3_alltoone = loss_all_gcn_lr3_alltoone.std(axis=1)

mean_loss_all_gcn_lr4_alltoone = loss_all_gcn_lr4_alltoone.mean(axis=1)
std_loss_all_gcn_lr4_alltoone = loss_all_gcn_lr4_alltoone.std(axis=1)

# RGCN
mean_loss_all_rgcn_lr1_alltoone = loss_all_rgcn_lr1_alltoone.mean(axis=1)
std_loss_all_rgcn_lr1_alltoone = loss_all_rgcn_lr1_alltoone.std(axis=1)

mean_loss_all_rgcn_lr2_alltoone = loss_all_rgcn_lr2_alltoone.mean(axis=1)
std_loss_all_rgcn_lr2_alltoone = loss_all_rgcn_lr2_alltoone.std(axis=1)

mean_loss_all_rgcn_lr3_alltoone = loss_all_rgcn_lr3_alltoone.mean(axis=1)
std_loss_all_rgcn_lr3_alltoone = loss_all_rgcn_lr3_alltoone.std(axis=1)

mean_loss_all_rgcn_lr4_alltoone = loss_all_rgcn_lr4_alltoone.mean(axis=1)
std_loss_all_rgcn_lr4_alltoone = loss_all_rgcn_lr4_alltoone.std(axis=1)

# GAT
mean_loss_all_gat_lr1_alltoone = loss_all_gat_lr1_alltoone.mean(axis=1)
std_loss_all_gat_lr1_alltoone = loss_all_gat_lr1_alltoone.std(axis=1)

mean_loss_all_gat_lr2_alltoone = loss_all_gat_lr2_alltoone.mean(axis=1)
std_loss_all_gat_lr2_alltoone = loss_all_gat_lr2_alltoone.std(axis=1)

mean_loss_all_gat_lr3_alltoone = loss_all_gat_lr3_alltoone.mean(axis=1)
std_loss_all_gat_lr3_alltoone = loss_all_gat_lr3_alltoone.std(axis=1)

mean_loss_all_gat_lr4_alltoone = loss_all_gat_lr4_alltoone.mean(axis=1)
std_loss_all_gat_lr4_alltoone = loss_all_gat_lr4_alltoone.std(axis=1)

# %%
# draw the lines for the means
plt.plot(mean_rec_loss_gae_lr1_alltoone.index.values, mean_rec_loss_gae_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_rec_loss_gae_lr2_alltoone.index.values, mean_rec_loss_gae_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_rec_loss_gae_lr3_alltoone.index.values, mean_rec_loss_gae_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
#plt.plot(mean_rec_loss_gae_lr4_alltoone.index.values, mean_rec_loss_gae_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_rec_loss_gae_lr1_alltoone.index.values, mean_rec_loss_gae_lr1_alltoone - std_rec_loss_gae_lr1_alltoone, mean_rec_loss_gae_lr1_alltoone + std_rec_loss_gae_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr2_alltoone.index.values, mean_rec_loss_gae_lr2_alltoone - std_rec_loss_gae_lr2_alltoone, mean_rec_loss_gae_lr2_alltoone + std_rec_loss_gae_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr3_alltoone.index.values, mean_rec_loss_gae_lr3_alltoone - std_rec_loss_gae_lr3_alltoone, mean_rec_loss_gae_lr3_alltoone + std_rec_loss_gae_lr3_alltoone, color='b', alpha=0.25)
#plt.fill_between(std_rec_loss_gae_lr4_alltoone.index.values, mean_rec_loss_gae_lr4_alltoone - std_rec_loss_gae_lr4_alltoone, mean_rec_loss_gae_lr4_alltoone + std_rec_loss_gae_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GAE for All-to-one DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gae_alltoone_rec_loss.png', dpi=300)

plt.show()

# %%
# adj rand
gae_lr1_alltoone_adj_rand_mean = mean([gae_lr1_s0_alltoone_final['Rand12'][0], gae_lr1_s0_alltoone_final['Rand23'][0], gae_lr1_s0_alltoone_final['Rand13'][0], gae_lr1_s1_alltoone_final['Rand12'][0], gae_lr1_s1_alltoone_final['Rand23'][0], gae_lr1_s1_alltoone_final['Rand13'][0], gae_lr1_s2_alltoone_final['Rand12'][0], gae_lr1_s2_alltoone_final['Rand23'][0], gae_lr1_s2_alltoone_final['Rand13'][0]])
gae_lr1_alltoone_adj_rand_std = std([gae_lr1_s0_alltoone_final['Rand12'][0], gae_lr1_s0_alltoone_final['Rand23'][0], gae_lr1_s0_alltoone_final['Rand13'][0], gae_lr1_s1_alltoone_final['Rand12'][0], gae_lr1_s1_alltoone_final['Rand23'][0], gae_lr1_s1_alltoone_final['Rand13'][0], gae_lr1_s2_alltoone_final['Rand12'][0], gae_lr1_s2_alltoone_final['Rand23'][0], gae_lr1_s2_alltoone_final['Rand13'][0]])

gae_lr2_alltoone_adj_rand_mean = mean([gae_lr2_s0_alltoone_final['Rand12'][0], gae_lr2_s0_alltoone_final['Rand23'][0], gae_lr2_s0_alltoone_final['Rand13'][0], gae_lr2_s1_alltoone_final['Rand12'][0], gae_lr2_s1_alltoone_final['Rand23'][0], gae_lr2_s1_alltoone_final['Rand13'][0], gae_lr2_s2_alltoone_final['Rand12'][0], gae_lr2_s2_alltoone_final['Rand23'][0], gae_lr2_s2_alltoone_final['Rand13'][0]])
gae_lr2_alltoone_adj_rand_std = std([gae_lr2_s0_alltoone_final['Rand12'][0], gae_lr2_s0_alltoone_final['Rand23'][0], gae_lr2_s0_alltoone_final['Rand13'][0], gae_lr2_s1_alltoone_final['Rand12'][0], gae_lr2_s1_alltoone_final['Rand23'][0], gae_lr2_s1_alltoone_final['Rand13'][0], gae_lr2_s2_alltoone_final['Rand12'][0], gae_lr2_s2_alltoone_final['Rand23'][0], gae_lr2_s2_alltoone_final['Rand13'][0]])

gae_lr3_alltoone_adj_rand_mean = mean([gae_lr3_s0_alltoone_final['Rand12'][0], gae_lr3_s0_alltoone_final['Rand23'][0], gae_lr3_s0_alltoone_final['Rand13'][0], gae_lr3_s1_alltoone_final['Rand12'][0], gae_lr3_s1_alltoone_final['Rand23'][0], gae_lr3_s1_alltoone_final['Rand13'][0], gae_lr3_s2_alltoone_final['Rand12'][0], gae_lr3_s2_alltoone_final['Rand23'][0], gae_lr3_s2_alltoone_final['Rand13'][0]])
gae_lr3_alltoone_adj_rand_std = std([gae_lr3_s0_alltoone_final['Rand12'][0], gae_lr3_s0_alltoone_final['Rand23'][0], gae_lr3_s0_alltoone_final['Rand13'][0], gae_lr3_s1_alltoone_final['Rand12'][0], gae_lr3_s1_alltoone_final['Rand23'][0], gae_lr3_s1_alltoone_final['Rand13'][0], gae_lr3_s2_alltoone_final['Rand12'][0], gae_lr3_s2_alltoone_final['Rand23'][0], gae_lr3_s2_alltoone_final['Rand13'][0]])

gae_lr4_alltoone_adj_rand_mean = mean([gae_lr4_s0_alltoone_final['Rand12'][0], gae_lr4_s0_alltoone_final['Rand23'][0], gae_lr4_s0_alltoone_final['Rand13'][0], gae_lr4_s1_alltoone_final['Rand12'][0], gae_lr4_s1_alltoone_final['Rand23'][0], gae_lr4_s1_alltoone_final['Rand13'][0], gae_lr4_s2_alltoone_final['Rand12'][0], gae_lr4_s2_alltoone_final['Rand23'][0], gae_lr4_s2_alltoone_final['Rand13'][0]])
gae_lr4_alltoone_adj_rand_std = std([gae_lr4_s0_alltoone_final['Rand12'][0], gae_lr4_s0_alltoone_final['Rand23'][0], gae_lr4_s0_alltoone_final['Rand13'][0], gae_lr4_s1_alltoone_final['Rand12'][0], gae_lr4_s1_alltoone_final['Rand23'][0], gae_lr4_s1_alltoone_final['Rand13'][0], gae_lr4_s2_alltoone_final['Rand12'][0], gae_lr4_s2_alltoone_final['Rand23'][0], gae_lr4_s2_alltoone_final['Rand13'][0]])

# bic score
gae_lr1_alltoone_bic_mean = mean([gae_lr1_s0_alltoone_final['BIC_1'][0], gae_lr1_s0_alltoone_final['BIC_2'][0], gae_lr1_s0_alltoone_final['BIC_3'][0], gae_lr1_s1_alltoone_final['BIC_1'][0], gae_lr1_s1_alltoone_final['BIC_2'][0], gae_lr1_s1_alltoone_final['BIC_3'][0], gae_lr1_s2_alltoone_final['BIC_1'][0], gae_lr1_s2_alltoone_final['BIC_2'][0], gae_lr1_s2_alltoone_final['BIC_3'][0]])
gae_lr1_alltoone_bic_std = std([gae_lr1_s0_alltoone_final['BIC_1'][0], gae_lr1_s0_alltoone_final['BIC_2'][0], gae_lr1_s0_alltoone_final['BIC_3'][0], gae_lr1_s1_alltoone_final['BIC_1'][0], gae_lr1_s1_alltoone_final['BIC_2'][0], gae_lr1_s1_alltoone_final['BIC_3'][0], gae_lr1_s2_alltoone_final['BIC_1'][0], gae_lr1_s2_alltoone_final['BIC_2'][0], gae_lr1_s2_alltoone_final['BIC_3'][0]])

gae_lr2_alltoone_bic_mean = mean([gae_lr2_s0_alltoone_final['BIC_1'][0], gae_lr2_s0_alltoone_final['BIC_2'][0], gae_lr2_s0_alltoone_final['BIC_3'][0], gae_lr2_s1_alltoone_final['BIC_1'][0], gae_lr2_s1_alltoone_final['BIC_2'][0], gae_lr2_s1_alltoone_final['BIC_3'][0], gae_lr2_s2_alltoone_final['BIC_1'][0], gae_lr2_s2_alltoone_final['BIC_2'][0], gae_lr2_s2_alltoone_final['BIC_3'][0]])
gae_lr2_alltoone_bic_std = std([gae_lr2_s0_alltoone_final['BIC_1'][0], gae_lr2_s0_alltoone_final['BIC_2'][0], gae_lr2_s0_alltoone_final['BIC_3'][0], gae_lr2_s1_alltoone_final['BIC_1'][0], gae_lr2_s1_alltoone_final['BIC_2'][0], gae_lr2_s1_alltoone_final['BIC_3'][0], gae_lr2_s2_alltoone_final['BIC_1'][0], gae_lr2_s2_alltoone_final['BIC_2'][0], gae_lr2_s2_alltoone_final['BIC_3'][0]])

gae_lr3_alltoone_bic_mean = mean([gae_lr3_s0_alltoone_final['BIC_1'][0], gae_lr3_s0_alltoone_final['BIC_2'][0], gae_lr3_s0_alltoone_final['BIC_3'][0], gae_lr3_s1_alltoone_final['BIC_1'][0], gae_lr3_s1_alltoone_final['BIC_2'][0], gae_lr3_s1_alltoone_final['BIC_3'][0], gae_lr3_s2_alltoone_final['BIC_1'][0], gae_lr3_s2_alltoone_final['BIC_2'][0], gae_lr3_s2_alltoone_final['BIC_3'][0]])
gae_lr3_alltoone_bic_std = std([gae_lr3_s0_alltoone_final['BIC_1'][0], gae_lr3_s0_alltoone_final['BIC_2'][0], gae_lr3_s0_alltoone_final['BIC_3'][0], gae_lr3_s1_alltoone_final['BIC_1'][0], gae_lr3_s1_alltoone_final['BIC_2'][0], gae_lr3_s1_alltoone_final['BIC_3'][0], gae_lr3_s2_alltoone_final['BIC_1'][0], gae_lr3_s2_alltoone_final['BIC_2'][0], gae_lr3_s2_alltoone_final['BIC_3'][0]])

gae_lr4_alltoone_bic_mean = mean([gae_lr4_s0_alltoone_final['BIC_1'][0], gae_lr4_s0_alltoone_final['BIC_2'][0], gae_lr4_s0_alltoone_final['BIC_3'][0], gae_lr4_s1_alltoone_final['BIC_1'][0], gae_lr4_s1_alltoone_final['BIC_2'][0], gae_lr4_s1_alltoone_final['BIC_3'][0], gae_lr4_s2_alltoone_final['BIC_1'][0], gae_lr4_s2_alltoone_final['BIC_2'][0], gae_lr4_s2_alltoone_final['BIC_3'][0]])
gae_lr4_alltoone_bic_std = std([gae_lr4_s0_alltoone_final['BIC_1'][0], gae_lr4_s0_alltoone_final['BIC_2'][0], gae_lr4_s0_alltoone_final['BIC_3'][0], gae_lr4_s1_alltoone_final['BIC_1'][0], gae_lr4_s1_alltoone_final['BIC_2'][0], gae_lr4_s1_alltoone_final['BIC_3'][0], gae_lr4_s2_alltoone_final['BIC_1'][0], gae_lr4_s2_alltoone_final['BIC_2'][0], gae_lr4_s2_alltoone_final['BIC_3'][0]])

# print results
print("Learning rate 0.001: Adj. Rand. Mean: ",gae_lr1_alltoone_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr1_alltoone_adj_rand_std, ", BIC Mean: ", gae_lr1_alltoone_bic_mean, ", BIC Std: ", gae_lr1_alltoone_bic_std)
print("Learning rate 0.005: Adj. Rand. Mean: ",gae_lr2_alltoone_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr2_alltoone_adj_rand_std, ", BIC Mean: ", gae_lr2_alltoone_bic_mean, ", BIC Std: ", gae_lr2_alltoone_bic_std)
print("Learning rate 0.01: Adj. Rand. Mean: ",gae_lr3_alltoone_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr3_alltoone_adj_rand_std, ", BIC Mean: ", gae_lr3_alltoone_bic_mean, ", BIC Std: ", gae_lr3_alltoone_bic_std)
print("Learning rate 0.1: Adj. Rand. Mean: ",gae_lr4_alltoone_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr4_alltoone_adj_rand_std, ", BIC Mean: ", gae_lr4_alltoone_bic_mean, ", BIC Std: ", gae_lr4_alltoone_bic_std)
# Out:
# Learning rate 0.001: Adj. Rand. Mean:  0.6786960864580881 , Adj. Rand. Std.:  0.331303822556512 , BIC Mean:  -337498.84758903657 , BIC Std:  32286.95437058214
# Learning rate 0.005: Adj. Rand. Mean:  0.7790248022510898 , Adj. Rand. Std.:  0.39981270947987574 , BIC Mean:  -912615.7107269627 , BIC Std:  906708.3071216678
# Learning rate 0.01: Adj. Rand. Mean:  0.5483716058959711 , Adj. Rand. Std.:  0.4485532545285184 , BIC Mean:  -1112980.5865487668 , BIC Std:  589847.7431091921
# Learning rate 0.1: Adj. Rand. Mean:  0.7786793259373762 , Adj. Rand. Std.:  0.43897219234461565 , BIC Mean:  1297696.839750239 , BIC Std:  227161.6592463537

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gcn_lr1_alltoone.index.values, mean_accuracy_all_gcn_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gcn_lr2_alltoone.index.values, mean_accuracy_all_gcn_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gcn_lr3_alltoone.index.values, mean_accuracy_all_gcn_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gcn_lr4_alltoone.index.values, mean_accuracy_all_gcn_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gcn_lr1_alltoone.index.values, mean_accuracy_all_gcn_lr1_alltoone - std_accuracy_all_gcn_lr1_alltoone, mean_accuracy_all_gcn_lr1_alltoone + std_accuracy_all_gcn_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr2_alltoone.index.values, mean_accuracy_all_gcn_lr2_alltoone - std_accuracy_all_gcn_lr2_alltoone, mean_accuracy_all_gcn_lr2_alltoone + std_accuracy_all_gcn_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr3_alltoone.index.values, mean_accuracy_all_gcn_lr3_alltoone - std_accuracy_all_gcn_lr3_alltoone, mean_accuracy_all_gcn_lr3_alltoone + std_accuracy_all_gcn_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr4_alltoone.index.values, mean_accuracy_all_gcn_lr4_alltoone - std_accuracy_all_gcn_lr4_alltoone, mean_accuracy_all_gcn_lr4_alltoone + std_accuracy_all_gcn_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GCN for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_altoone_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gcn_lr1_alltoone.index.values, mean_loss_all_gcn_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gcn_lr2_alltoone.index.values, mean_loss_all_gcn_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gcn_lr3_alltoone.index.values, mean_loss_all_gcn_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gcn_lr4_alltoone.index.values, mean_loss_all_gcn_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gcn_lr1_alltoone.index.values, mean_loss_all_gcn_lr1_alltoone - std_loss_all_gcn_lr1_alltoone, mean_loss_all_gcn_lr1_alltoone + std_loss_all_gcn_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr2_alltoone.index.values, mean_loss_all_gcn_lr2_alltoone - std_loss_all_gcn_lr2_alltoone, mean_loss_all_gcn_lr2_alltoone + std_loss_all_gcn_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr3_alltoone.index.values, mean_loss_all_gcn_lr3_alltoone - std_loss_all_gcn_lr3_alltoone, mean_loss_all_gcn_lr3_alltoone + std_loss_all_gcn_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr4_alltoone.index.values, mean_loss_all_gcn_lr4_alltoone - std_loss_all_gcn_lr4_alltoone, mean_loss_all_gcn_lr4_alltoone + std_loss_all_gcn_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GCN for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_alltoone_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_rgcn_lr1_alltoone.index.values, mean_accuracy_all_rgcn_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_rgcn_lr2_alltoone.index.values, mean_accuracy_all_rgcn_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_rgcn_lr3_alltoone.index.values, mean_accuracy_all_rgcn_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_rgcn_lr4_alltoone.index.values, mean_accuracy_all_rgcn_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_rgcn_lr1_alltoone.index.values, mean_accuracy_all_rgcn_lr1_alltoone - std_accuracy_all_rgcn_lr1_alltoone, mean_accuracy_all_rgcn_lr1_alltoone + std_accuracy_all_rgcn_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr2_alltoone.index.values, mean_accuracy_all_rgcn_lr2_alltoone - std_accuracy_all_rgcn_lr2_alltoone, mean_accuracy_all_rgcn_lr2_alltoone + std_accuracy_all_rgcn_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr3_alltoone.index.values, mean_accuracy_all_rgcn_lr3_alltoone - std_accuracy_all_rgcn_lr3_alltoone, mean_accuracy_all_rgcn_lr3_alltoone + std_accuracy_all_rgcn_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr4_alltoone.index.values, mean_accuracy_all_rgcn_lr4_alltoone - std_accuracy_all_rgcn_lr4_alltoone, mean_accuracy_all_rgcn_lr4_alltoone + std_accuracy_all_rgcn_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of R-GCN for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_altoone_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_rgcn_lr1_alltoone.index.values, mean_loss_all_rgcn_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_rgcn_lr2_alltoone.index.values, mean_loss_all_rgcn_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_rgcn_lr3_alltoone.index.values, mean_loss_all_rgcn_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_rgcn_lr4_alltoone.index.values, mean_loss_all_rgcn_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_rgcn_lr1_alltoone.index.values, mean_loss_all_rgcn_lr1_alltoone - std_loss_all_rgcn_lr1_alltoone, mean_loss_all_rgcn_lr1_alltoone + std_loss_all_rgcn_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr2_alltoone.index.values, mean_loss_all_rgcn_lr2_alltoone - std_loss_all_rgcn_lr2_alltoone, mean_loss_all_rgcn_lr2_alltoone + std_loss_all_rgcn_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr3_alltoone.index.values, mean_loss_all_rgcn_lr3_alltoone - std_loss_all_rgcn_lr3_alltoone, mean_loss_all_rgcn_lr3_alltoone + std_loss_all_rgcn_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr4_alltoone.index.values, mean_loss_all_rgcn_lr4_alltoone - std_loss_all_rgcn_lr4_alltoone, mean_loss_all_rgcn_lr4_alltoone + std_loss_all_rgcn_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of R-GCN for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_alltoone_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gat_lr1_alltoone.index.values, mean_accuracy_all_gat_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gat_lr2_alltoone.index.values, mean_accuracy_all_gat_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gat_lr3_alltoone.index.values, mean_accuracy_all_gat_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gat_lr4_alltoone.index.values, mean_accuracy_all_gat_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gat_lr1_alltoone.index.values, mean_accuracy_all_gat_lr1_alltoone - std_accuracy_all_gat_lr1_alltoone, mean_accuracy_all_gat_lr1_alltoone + std_accuracy_all_gat_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr2_alltoone.index.values, mean_accuracy_all_gat_lr2_alltoone - std_accuracy_all_gat_lr2_alltoone, mean_accuracy_all_gat_lr2_alltoone + std_accuracy_all_gat_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr3_alltoone.index.values, mean_accuracy_all_gat_lr3_alltoone - std_accuracy_all_gat_lr3_alltoone, mean_accuracy_all_gat_lr3_alltoone + std_accuracy_all_gat_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr4_alltoone.index.values, mean_accuracy_all_gat_lr4_alltoone - std_accuracy_all_gat_lr4_alltoone, mean_accuracy_all_gat_lr4_alltoone + std_accuracy_all_gat_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GAT for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_altoone_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gat_lr1_alltoone.index.values, mean_loss_all_gat_lr1_alltoone, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gat_lr2_alltoone.index.values, mean_loss_all_gat_lr2_alltoone, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gat_lr3_alltoone.index.values, mean_loss_all_gat_lr3_alltoone, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gat_lr4_alltoone.index.values, mean_loss_all_gat_lr4_alltoone, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gat_lr1_alltoone.index.values, mean_loss_all_gat_lr1_alltoone - std_loss_all_gat_lr1_alltoone, mean_loss_all_gat_lr1_alltoone + std_loss_all_gat_lr1_alltoone, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr2_alltoone.index.values, mean_loss_all_gat_lr2_alltoone - std_loss_all_gat_lr2_alltoone, mean_loss_all_gat_lr2_alltoone + std_loss_all_gat_lr2_alltoone, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr3_alltoone.index.values, mean_loss_all_gat_lr3_alltoone - std_loss_all_gat_lr3_alltoone, mean_loss_all_gat_lr3_alltoone + std_loss_all_gat_lr3_alltoone, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr4_alltoone.index.values, mean_loss_all_gat_lr4_alltoone - std_loss_all_gat_lr4_alltoone, mean_loss_all_gat_lr4_alltoone + std_loss_all_gat_lr4_alltoone, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GAT for All-to-One DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_alltoone_valloss.png', dpi=300)

plt.show()

# %% [markdown]
# ### Collapsed:

# %%
# concatenate all these results
# only for the reconstruction loss (no wd used here)
rec_loss_gae_lr1_collapsed = pd.concat([gae_lr1_s0_collapsed['ReconLossTrain'], gae_lr1_s1_collapsed['ReconLossTrain'], gae_lr1_s2_collapsed['ReconLossTrain']], axis=1)
rec_loss_gae_lr2_collapsed = pd.concat([gae_lr2_s0_collapsed['ReconLossTrain'], gae_lr2_s1_collapsed['ReconLossTrain'], gae_lr2_s2_collapsed['ReconLossTrain']], axis=1)
rec_loss_gae_lr3_collapsed = pd.concat([gae_lr3_s0_collapsed['ReconLossTrain'], gae_lr3_s1_collapsed['ReconLossTrain'], gae_lr3_s2_collapsed['ReconLossTrain']], axis=1)
rec_loss_gae_lr4_collapsed = pd.concat([gae_lr4_s0_collapsed['ReconLossTrain'], gae_lr4_s1_collapsed['ReconLossTrain'], gae_lr4_s2_collapsed['ReconLossTrain']], axis=1)

# ---- GCN ------
accuracy_all_gcn_lr1_collapsed = pd.concat([gcn_lr1_s0_collapsed['AccTest'], gcn_lr1_s1_collapsed['AccTest'], gcn_lr1_s2_collapsed['AccTest']], axis=1)
loss_all_gcn_lr1_collapsed = pd.concat([gcn_lr1_s0_collapsed['CrossEntropyLossTest'], gcn_lr1_s1_collapsed['CrossEntropyLossTest'], gcn_lr1_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr2_collapsed = pd.concat([gcn_lr2_s0_collapsed['AccTest'], gcn_lr2_s1_collapsed['AccTest'], gcn_lr2_s2_collapsed['AccTest']], axis=1)
loss_all_gcn_lr2_collapsed = pd.concat([gcn_lr2_s0_collapsed['CrossEntropyLossTest'], gcn_lr2_s1_collapsed['CrossEntropyLossTest'], gcn_lr2_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr3_collapsed = pd.concat([gcn_lr3_s0_collapsed['AccTest'], gcn_lr3_s1_collapsed['AccTest'], gcn_lr3_s2_collapsed['AccTest']], axis=1)
loss_all_gcn_lr3_collapsed = pd.concat([gcn_lr3_s0_collapsed['CrossEntropyLossTest'], gcn_lr3_s1_collapsed['CrossEntropyLossTest'], gcn_lr3_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr4_collapsed = pd.concat([gcn_lr4_s0_collapsed['AccTest'], gcn_lr4_s1_collapsed['AccTest'], gcn_lr4_s2_collapsed['AccTest']], axis=1)
loss_all_gcn_lr4_collapsed = pd.concat([gcn_lr4_s0_collapsed['CrossEntropyLossTest'], gcn_lr4_s1_collapsed['CrossEntropyLossTest'], gcn_lr4_s2_collapsed['CrossEntropyLossTest']], axis=1)

# ---- RGCN ------
accuracy_all_rgcn_lr1_collapsed = pd.concat([rgcn_lr1_s0_collapsed['AccTest'], rgcn_lr1_s1_collapsed['AccTest'], rgcn_lr1_s2_collapsed['AccTest']], axis=1)
loss_all_rgcn_lr1_collapsed = pd.concat([rgcn_lr1_s0_collapsed['CrossEntropyLossTest'], rgcn_lr1_s1_collapsed['CrossEntropyLossTest'], rgcn_lr1_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr2_collapsed = pd.concat([rgcn_lr2_s0_collapsed['AccTest'], rgcn_lr2_s1_collapsed['AccTest'], rgcn_lr2_s2_collapsed['AccTest']], axis=1)
loss_all_rgcn_lr2_collapsed = pd.concat([rgcn_lr2_s0_collapsed['CrossEntropyLossTest'], rgcn_lr2_s1_collapsed['CrossEntropyLossTest'], rgcn_lr2_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr3_collapsed = pd.concat([rgcn_lr3_s0_collapsed['AccTest'], rgcn_lr3_s1_collapsed['AccTest'], rgcn_lr3_s2_collapsed['AccTest']], axis=1)
loss_all_rgcn_lr3_collapsed = pd.concat([rgcn_lr3_s0_collapsed['CrossEntropyLossTest'], rgcn_lr3_s1_collapsed['CrossEntropyLossTest'], rgcn_lr3_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr4_collapsed = pd.concat([rgcn_lr4_s0_collapsed['AccTest'], rgcn_lr4_s1_collapsed['AccTest'], rgcn_lr4_s2_collapsed['AccTest']], axis=1)
loss_all_rgcn_lr4_collapsed = pd.concat([rgcn_lr4_s0_collapsed['CrossEntropyLossTest'], rgcn_lr4_s1_collapsed['CrossEntropyLossTest'], rgcn_lr4_s2_collapsed['CrossEntropyLossTest']], axis=1)

# ---- GAT ------
accuracy_all_gat_lr1_collapsed = pd.concat([gat_lr1_s0_collapsed['AccTest'], gat_lr1_s1_collapsed['AccTest'], gat_lr1_s2_collapsed['AccTest']], axis=1)
loss_all_gat_lr1_collapsed = pd.concat([gat_lr1_s0_collapsed['CrossEntropyLossTest'], gat_lr1_s1_collapsed['CrossEntropyLossTest'], gat_lr1_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr2_collapsed = pd.concat([gat_lr2_s0_collapsed['AccTest'], gat_lr2_s1_collapsed['AccTest'], gat_lr2_s2_collapsed['AccTest']], axis=1)
loss_all_gat_lr2_collapsed = pd.concat([gat_lr2_s0_collapsed['CrossEntropyLossTest'], gat_lr2_s1_collapsed['CrossEntropyLossTest'], gat_lr2_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr3_collapsed = pd.concat([gat_lr3_s0_collapsed['AccTest'], gat_lr3_s1_collapsed['AccTest'], gat_lr3_s2_collapsed['AccTest']], axis=1)
loss_all_gat_lr3_collapsed = pd.concat([gat_lr3_s0_collapsed['CrossEntropyLossTest'], gat_lr3_s1_collapsed['CrossEntropyLossTest'], gat_lr3_s2_collapsed['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr4_collapsed = pd.concat([gat_lr4_s0_collapsed['AccTest'], gat_lr4_s1_collapsed['AccTest'], gat_lr4_s2_collapsed['AccTest']], axis=1)
loss_all_gat_lr4_collapsed = pd.concat([gat_lr4_s0_collapsed['CrossEntropyLossTest'], gat_lr4_s1_collapsed['CrossEntropyLossTest'], gat_lr4_s2_collapsed['CrossEntropyLossTest']], axis=1)

# %%
# get the mean and std of all these results!
# GCN
mean_accuracy_all_gcn_lr1_collapsed = accuracy_all_gcn_lr1_collapsed.mean(axis=1)
std_accuracy_all_gcn_lr1_collapsed = accuracy_all_gcn_lr1_collapsed.std(axis=1)

mean_accuracy_all_gcn_lr2_collapsed = accuracy_all_gcn_lr2_collapsed.mean(axis=1)
std_accuracy_all_gcn_lr2_collapsed= accuracy_all_gcn_lr2_collapsed.std(axis=1)

mean_accuracy_all_gcn_lr3_collapsed = accuracy_all_gcn_lr3_collapsed.mean(axis=1)
std_accuracy_all_gcn_lr3_collapsed = accuracy_all_gcn_lr3_collapsed.std(axis=1)

mean_accuracy_all_gcn_lr4_collapsed = accuracy_all_gcn_lr4_collapsed.mean(axis=1)
std_accuracy_all_gcn_lr4_collapsed = accuracy_all_gcn_lr4_collapsed.std(axis=1)

# RGCN
mean_accuracy_all_rgcn_lr1_collapsed = accuracy_all_rgcn_lr1_collapsed.mean(axis=1)
std_accuracy_all_rgcn_lr1_collapsed = accuracy_all_rgcn_lr1_collapsed.std(axis=1)

mean_accuracy_all_rgcn_lr2_collapsed = accuracy_all_rgcn_lr2_collapsed.mean(axis=1)
std_accuracy_all_rgcn_lr2_collapsed = accuracy_all_rgcn_lr2_collapsed.std(axis=1)

mean_accuracy_all_rgcn_lr3_collapsed = accuracy_all_rgcn_lr3_collapsed.mean(axis=1)
std_accuracy_all_rgcn_lr3_collapsed = accuracy_all_rgcn_lr3_collapsed.std(axis=1)

mean_accuracy_all_rgcn_lr4_collapsed = accuracy_all_rgcn_lr4_collapsed.mean(axis=1)
std_accuracy_all_rgcn_lr4_collapsed = accuracy_all_rgcn_lr4_collapsed.std(axis=1)

# GAT
mean_accuracy_all_gat_lr1_collapsed = accuracy_all_gat_lr1_collapsed.mean(axis=1)
std_accuracy_all_gat_lr1_collapsed = accuracy_all_gat_lr1_collapsed.std(axis=1)

mean_accuracy_all_gat_lr2_collapsed = accuracy_all_gat_lr2_collapsed.mean(axis=1)
std_accuracy_all_gat_lr2_collapsed = accuracy_all_gat_lr2_collapsed.std(axis=1)

mean_accuracy_all_gat_lr3_collapsed = accuracy_all_gat_lr3_collapsed.mean(axis=1)
std_accuracy_all_gat_lr3_collapsed = accuracy_all_gat_lr3_collapsed.std(axis=1)

mean_accuracy_all_gat_lr4_collapsed = accuracy_all_gat_lr4_collapsed.mean(axis=1)
std_accuracy_all_gat_lr4_collapsed = accuracy_all_gat_lr4_collapsed.std(axis=1)

# %%
# GAE
mean_rec_loss_gae_lr1_collapsed = rec_loss_gae_lr1_collapsed.mean(axis=1)
std_rec_loss_gae_lr1_collapsed = rec_loss_gae_lr1_collapsed.std(axis=1)

mean_rec_loss_gae_lr2_collapsed = rec_loss_gae_lr2_collapsed.mean(axis=1)
std_rec_loss_gae_lr2_collapsed = rec_loss_gae_lr2_collapsed.std(axis=1)

mean_rec_loss_gae_lr3_collapsed = rec_loss_gae_lr3_collapsed.mean(axis=1)
std_rec_loss_gae_lr3_collapsed = rec_loss_gae_lr3_collapsed.std(axis=1)

mean_rec_loss_gae_lr4_collapsed = rec_loss_gae_lr4_collapsed.mean(axis=1)
std_rec_loss_gae_lr4_collapsed = rec_loss_gae_lr4_collapsed.std(axis=1)

# GCN
mean_loss_all_gcn_lr1_collapsed = loss_all_gcn_lr1_collapsed.mean(axis=1)
std_loss_all_gcn_lr1_collapsed = loss_all_gcn_lr1_collapsed.std(axis=1)

mean_loss_all_gcn_lr2_collapsed = loss_all_gcn_lr2_collapsed.mean(axis=1)
std_loss_all_gcn_lr2_collapsed = loss_all_gcn_lr2_collapsed.std(axis=1)

mean_loss_all_gcn_lr3_collapsed = loss_all_gcn_lr3_collapsed.mean(axis=1)
std_loss_all_gcn_lr3_collapsed = loss_all_gcn_lr3_collapsed.std(axis=1)

mean_loss_all_gcn_lr4_collapsed = loss_all_gcn_lr4_collapsed.mean(axis=1)
std_loss_all_gcn_lr4_collapsed = loss_all_gcn_lr4_collapsed.std(axis=1)

# RGCN
mean_loss_all_rgcn_lr1_collapsed = loss_all_rgcn_lr1_collapsed.mean(axis=1)
std_loss_all_rgcn_lr1_collapsed = loss_all_rgcn_lr1_collapsed.std(axis=1)

mean_loss_all_rgcn_lr2_collapsed = loss_all_rgcn_lr2_collapsed.mean(axis=1)
std_loss_all_rgcn_lr2_collapsed = loss_all_rgcn_lr2_collapsed.std(axis=1)

mean_loss_all_rgcn_lr3_collapsed = loss_all_rgcn_lr3_collapsed.mean(axis=1)
std_loss_all_rgcn_lr3_collapsed = loss_all_rgcn_lr3_collapsed.std(axis=1)

mean_loss_all_rgcn_lr4_collapsed = loss_all_rgcn_lr4_collapsed.mean(axis=1)
std_loss_all_rgcn_lr4_collapsed = loss_all_rgcn_lr4_collapsed.std(axis=1)

# GAT
mean_loss_all_gat_lr1_collapsed = loss_all_gat_lr1_collapsed.mean(axis=1)
std_loss_all_gat_lr1_collapsed = loss_all_gat_lr1_collapsed.std(axis=1)

mean_loss_all_gat_lr2_collapsed = loss_all_gat_lr2_collapsed.mean(axis=1)
std_loss_all_gat_lr2_collapsed = loss_all_gat_lr2_collapsed.std(axis=1)

mean_loss_all_gat_lr3_collapsed = loss_all_gat_lr3_collapsed.mean(axis=1)
std_loss_all_gat_lr3_collapsed = loss_all_gat_lr3_collapsed.std(axis=1)

mean_loss_all_gat_lr4_collapsed = loss_all_gat_lr4_collapsed.mean(axis=1)
std_loss_all_gat_lr4_collapsed = loss_all_gat_lr4_collapsed.std(axis=1)

# %%
# draw the lines for the means
plt.plot(mean_rec_loss_gae_lr1_collapsed.index.values, mean_rec_loss_gae_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_rec_loss_gae_lr2_collapsed.index.values, mean_rec_loss_gae_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_rec_loss_gae_lr3_collapsed.index.values, mean_rec_loss_gae_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
#plt.plot(mean_rec_loss_gae_lr4_collapsed.index.values, mean_rec_loss_gae_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_rec_loss_gae_lr1_collapsed.index.values, mean_rec_loss_gae_lr1_collapsed - std_rec_loss_gae_lr1_collapsed, mean_rec_loss_gae_lr1_collapsed + std_rec_loss_gae_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr2_collapsed.index.values, mean_rec_loss_gae_lr2_collapsed - std_rec_loss_gae_lr2_collapsed, mean_rec_loss_gae_lr2_collapsed + std_rec_loss_gae_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr3_collapsed.index.values, mean_rec_loss_gae_lr3_collapsed - std_rec_loss_gae_lr3_collapsed, mean_rec_loss_gae_lr3_collapsed + std_rec_loss_gae_lr3_collapsed, color='b', alpha=0.25)
#plt.fill_between(std_rec_loss_gae_lr4_collapsed.index.values, mean_rec_loss_gae_lr4_collapsed - std_rec_loss_gae_lr4_collapsed, mean_rec_loss_gae_lr4_collapsed + std_rec_loss_gae_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Reconstruction Loss of GAE for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Reconstruction Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gae_collapsed_rec_loss.png', dpi=300)

plt.show()

# %%
# adj rand
gae_lr1_collapsed_adj_rand_mean = mean([gae_lr1_s0_collapsed_final['Rand12'][0], gae_lr1_s0_collapsed_final['Rand23'][0], gae_lr1_s0_collapsed_final['Rand13'][0], gae_lr1_s1_collapsed_final['Rand12'][0], gae_lr1_s1_collapsed_final['Rand23'][0], gae_lr1_s1_collapsed_final['Rand13'][0], gae_lr1_s2_collapsed_final['Rand12'][0], gae_lr1_s2_collapsed_final['Rand23'][0], gae_lr1_s2_collapsed_final['Rand13'][0]])
gae_lr1_collapsed_adj_rand_std = std([gae_lr1_s0_collapsed_final['Rand12'][0], gae_lr1_s0_collapsed_final['Rand23'][0], gae_lr1_s0_collapsed_final['Rand13'][0], gae_lr1_s1_collapsed_final['Rand12'][0], gae_lr1_s1_collapsed_final['Rand23'][0], gae_lr1_s1_collapsed_final['Rand13'][0], gae_lr1_s2_collapsed_final['Rand12'][0], gae_lr1_s2_collapsed_final['Rand23'][0], gae_lr1_s2_collapsed_final['Rand13'][0]])

gae_lr2_collapsed_adj_rand_mean = mean([gae_lr2_s0_collapsed_final['Rand12'][0], gae_lr2_s0_collapsed_final['Rand23'][0], gae_lr2_s0_collapsed_final['Rand13'][0], gae_lr2_s1_collapsed_final['Rand12'][0], gae_lr2_s1_collapsed_final['Rand23'][0], gae_lr2_s1_collapsed_final['Rand13'][0], gae_lr2_s2_collapsed_final['Rand12'][0], gae_lr2_s2_collapsed_final['Rand23'][0], gae_lr2_s2_collapsed_final['Rand13'][0]])
gae_lr2_collapsed_adj_rand_std = std([gae_lr2_s0_collapsed_final['Rand12'][0], gae_lr2_s0_collapsed_final['Rand23'][0], gae_lr2_s0_collapsed_final['Rand13'][0], gae_lr2_s1_collapsed_final['Rand12'][0], gae_lr2_s1_collapsed_final['Rand23'][0], gae_lr2_s1_collapsed_final['Rand13'][0], gae_lr2_s2_collapsed_final['Rand12'][0], gae_lr2_s2_collapsed_final['Rand23'][0], gae_lr2_s2_collapsed_final['Rand13'][0]])

gae_lr3_collapsed_adj_rand_mean = mean([gae_lr3_s0_collapsed_final['Rand12'][0], gae_lr3_s0_collapsed_final['Rand23'][0], gae_lr3_s0_collapsed_final['Rand13'][0], gae_lr3_s1_collapsed_final['Rand12'][0], gae_lr3_s1_collapsed_final['Rand23'][0], gae_lr3_s1_collapsed_final['Rand13'][0], gae_lr3_s2_collapsed_final['Rand12'][0], gae_lr3_s2_collapsed_final['Rand23'][0], gae_lr3_s2_collapsed_final['Rand13'][0]])
gae_lr3_collapsed_adj_rand_std = std([gae_lr3_s0_collapsed_final['Rand12'][0], gae_lr3_s0_collapsed_final['Rand23'][0], gae_lr3_s0_collapsed_final['Rand13'][0], gae_lr3_s1_collapsed_final['Rand12'][0], gae_lr3_s1_collapsed_final['Rand23'][0], gae_lr3_s1_collapsed_final['Rand13'][0], gae_lr3_s2_collapsed_final['Rand12'][0], gae_lr3_s2_collapsed_final['Rand23'][0], gae_lr3_s2_collapsed_final['Rand13'][0]])

gae_lr4_collapsed_adj_rand_mean = mean([gae_lr4_s0_collapsed_final['Rand12'][0], gae_lr4_s0_collapsed_final['Rand23'][0], gae_lr4_s0_collapsed_final['Rand13'][0], gae_lr4_s1_collapsed_final['Rand12'][0], gae_lr4_s1_collapsed_final['Rand23'][0], gae_lr4_s1_collapsed_final['Rand13'][0], gae_lr4_s2_collapsed_final['Rand12'][0], gae_lr4_s2_collapsed_final['Rand23'][0], gae_lr4_s2_collapsed_final['Rand13'][0]])
gae_lr4_collapsed_adj_rand_std = std([gae_lr4_s0_collapsed_final['Rand12'][0], gae_lr4_s0_collapsed_final['Rand23'][0], gae_lr4_s0_collapsed_final['Rand13'][0], gae_lr4_s1_collapsed_final['Rand12'][0], gae_lr4_s1_collapsed_final['Rand23'][0], gae_lr4_s1_collapsed_final['Rand13'][0], gae_lr4_s2_collapsed_final['Rand12'][0], gae_lr4_s2_collapsed_final['Rand23'][0], gae_lr4_s2_collapsed_final['Rand13'][0]])

# bic score
gae_lr1_collapsed_bic_mean = mean([gae_lr1_s0_collapsed_final['BIC_1'][0], gae_lr1_s0_collapsed_final['BIC_2'][0], gae_lr1_s0_collapsed_final['BIC_3'][0], gae_lr1_s1_collapsed_final['BIC_1'][0], gae_lr1_s1_collapsed_final['BIC_2'][0], gae_lr1_s1_collapsed_final['BIC_3'][0], gae_lr1_s2_collapsed_final['BIC_1'][0], gae_lr1_s2_collapsed_final['BIC_2'][0], gae_lr1_s2_collapsed_final['BIC_3'][0]])
gae_lr1_collapsed_bic_std = std([gae_lr1_s0_collapsed_final['BIC_1'][0], gae_lr1_s0_collapsed_final['BIC_2'][0], gae_lr1_s0_collapsed_final['BIC_3'][0], gae_lr1_s1_collapsed_final['BIC_1'][0], gae_lr1_s1_collapsed_final['BIC_2'][0], gae_lr1_s1_collapsed_final['BIC_3'][0], gae_lr1_s2_collapsed_final['BIC_1'][0], gae_lr1_s2_collapsed_final['BIC_2'][0], gae_lr1_s2_collapsed_final['BIC_3'][0]])

gae_lr2_collapsed_bic_mean = mean([gae_lr2_s0_collapsed_final['BIC_1'][0], gae_lr2_s0_collapsed_final['BIC_2'][0], gae_lr2_s0_collapsed_final['BIC_3'][0], gae_lr2_s1_collapsed_final['BIC_1'][0], gae_lr2_s1_collapsed_final['BIC_2'][0], gae_lr2_s1_collapsed_final['BIC_3'][0], gae_lr2_s2_collapsed_final['BIC_1'][0], gae_lr2_s2_collapsed_final['BIC_2'][0], gae_lr2_s2_collapsed_final['BIC_3'][0]])
gae_lr2_collapsed_bic_std = std([gae_lr2_s0_collapsed_final['BIC_1'][0], gae_lr2_s0_collapsed_final['BIC_2'][0], gae_lr2_s0_collapsed_final['BIC_3'][0], gae_lr2_s1_collapsed_final['BIC_1'][0], gae_lr2_s1_collapsed_final['BIC_2'][0], gae_lr2_s1_collapsed_final['BIC_3'][0], gae_lr2_s2_collapsed_final['BIC_1'][0], gae_lr2_s2_collapsed_final['BIC_2'][0], gae_lr2_s2_collapsed_final['BIC_3'][0]])

gae_lr3_collapsed_bic_mean = mean([gae_lr3_s0_collapsed_final['BIC_1'][0], gae_lr3_s0_collapsed_final['BIC_2'][0], gae_lr3_s0_collapsed_final['BIC_3'][0], gae_lr3_s1_collapsed_final['BIC_1'][0], gae_lr3_s1_collapsed_final['BIC_2'][0], gae_lr3_s1_collapsed_final['BIC_3'][0], gae_lr3_s2_collapsed_final['BIC_1'][0], gae_lr3_s2_collapsed_final['BIC_2'][0], gae_lr3_s2_collapsed_final['BIC_3'][0]])
gae_lr3_collapsed_bic_std = std([gae_lr3_s0_collapsed_final['BIC_1'][0], gae_lr3_s0_collapsed_final['BIC_2'][0], gae_lr3_s0_collapsed_final['BIC_3'][0], gae_lr3_s1_collapsed_final['BIC_1'][0], gae_lr3_s1_collapsed_final['BIC_2'][0], gae_lr3_s1_collapsed_final['BIC_3'][0], gae_lr3_s2_collapsed_final['BIC_1'][0], gae_lr3_s2_collapsed_final['BIC_2'][0], gae_lr3_s2_collapsed_final['BIC_3'][0]])

gae_lr4_collapsed_bic_mean = mean([gae_lr4_s0_collapsed_final['BIC_1'][0], gae_lr4_s0_collapsed_final['BIC_2'][0], gae_lr4_s0_collapsed_final['BIC_3'][0], gae_lr4_s1_collapsed_final['BIC_1'][0], gae_lr4_s1_collapsed_final['BIC_2'][0], gae_lr4_s1_collapsed_final['BIC_3'][0], gae_lr4_s2_collapsed_final['BIC_1'][0], gae_lr4_s2_collapsed_final['BIC_2'][0], gae_lr4_s2_collapsed_final['BIC_3'][0]])
gae_lr4_collapsed_bic_std = std([gae_lr4_s0_collapsed_final['BIC_1'][0], gae_lr4_s0_collapsed_final['BIC_2'][0], gae_lr4_s0_collapsed_final['BIC_3'][0], gae_lr4_s1_collapsed_final['BIC_1'][0], gae_lr4_s1_collapsed_final['BIC_2'][0], gae_lr4_s1_collapsed_final['BIC_3'][0], gae_lr4_s2_collapsed_final['BIC_1'][0], gae_lr4_s2_collapsed_final['BIC_2'][0], gae_lr4_s2_collapsed_final['BIC_3'][0]])

# print results
print("Learning rate 0.001: Adj. Rand. Mean: ",gae_lr1_collapsed_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr1_collapsed_adj_rand_std, ", BIC Mean: ", gae_lr1_collapsed_bic_mean, ", BIC Std: ", gae_lr1_collapsed_bic_std)
print("Learning rate 0.005: Adj. Rand. Mean: ",gae_lr2_collapsed_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr2_collapsed_adj_rand_std, ", BIC Mean: ", gae_lr2_collapsed_bic_mean, ", BIC Std: ", gae_lr2_collapsed_bic_std)
print("Learning rate 0.01: Adj. Rand. Mean: ",gae_lr3_collapsed_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr3_collapsed_adj_rand_std, ", BIC Mean: ", gae_lr3_collapsed_bic_mean, ", BIC Std: ", gae_lr3_collapsed_bic_std)
print("Learning rate 0.1: Adj. Rand. Mean: ",gae_lr4_collapsed_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr4_collapsed_adj_rand_std, ", BIC Mean: ", gae_lr4_collapsed_bic_mean, ", BIC Std: ", gae_lr4_collapsed_bic_std)
# Out:
# Learning rate 0.001: Adj. Rand. Mean:  0.8009768910266724 , Adj. Rand. Std.:  0.3172189700275712 , BIC Mean:  175436.96031017523 , BIC Std:  70466.30744694377
# Learning rate 0.005: Adj. Rand. Mean:  0.41210715143457977 , Adj. Rand. Std.:  0.39495167434150746 , BIC Mean:  273409.931690226 , BIC Std:  5420.535319827988
# Learning rate 0.01: Adj. Rand. Mean:  0.5992577271766739 , Adj. Rand. Std.:  0.47463143368405236 , BIC Mean:  -2571730.9705974623 , BIC Std:  2164972.540015479
# Learning rate 0.1: Adj. Rand. Mean:  0.7953871674242741 , Adj. Rand. Std.:  0.3991338115119095 , BIC Mean:  2979609.92770009 , BIC Std:  192062.73931204225

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gcn_lr1_collapsed.index.values, mean_accuracy_all_gcn_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gcn_lr2_collapsed.index.values, mean_accuracy_all_gcn_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gcn_lr3_collapsed.index.values, mean_accuracy_all_gcn_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gcn_lr4_collapsed.index.values, mean_accuracy_all_gcn_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gcn_lr1_collapsed.index.values, mean_accuracy_all_gcn_lr1_collapsed - std_accuracy_all_gcn_lr1_collapsed, mean_accuracy_all_gcn_lr1_collapsed + std_accuracy_all_gcn_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr2_collapsed.index.values, mean_accuracy_all_gcn_lr2_collapsed - std_accuracy_all_gcn_lr2_collapsed, mean_accuracy_all_gcn_lr2_collapsed + std_accuracy_all_gcn_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr3_collapsed.index.values, mean_accuracy_all_gcn_lr3_collapsed - std_accuracy_all_gcn_lr3_collapsed, mean_accuracy_all_gcn_lr3_collapsed + std_accuracy_all_gcn_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr4_collapsed.index.values, mean_accuracy_all_gcn_lr4_collapsed - std_accuracy_all_gcn_lr4_collapsed, mean_accuracy_all_gcn_lr4_collapsed + std_accuracy_all_gcn_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GCN for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_collapsed_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gcn_lr1_collapsed.index.values, mean_loss_all_gcn_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gcn_lr2_collapsed.index.values, mean_loss_all_gcn_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gcn_lr3_collapsed.index.values, mean_loss_all_gcn_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gcn_lr4_collapsed.index.values, mean_loss_all_gcn_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gcn_lr1_collapsed.index.values, mean_loss_all_gcn_lr1_collapsed - std_loss_all_gcn_lr1_collapsed, mean_loss_all_gcn_lr1_collapsed + std_loss_all_gcn_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr2_collapsed.index.values, mean_loss_all_gcn_lr2_collapsed - std_loss_all_gcn_lr2_collapsed, mean_loss_all_gcn_lr2_collapsed + std_loss_all_gcn_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr3_collapsed.index.values, mean_loss_all_gcn_lr3_collapsed - std_loss_all_gcn_lr3_collapsed, mean_loss_all_gcn_lr3_collapsed + std_loss_all_gcn_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr4_collapsed.index.values, mean_loss_all_gcn_lr4_collapsed - std_loss_all_gcn_lr4_collapsed, mean_loss_all_gcn_lr4_collapsed + std_loss_all_gcn_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GCN for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_collapsed_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_rgcn_lr1_collapsed.index.values, mean_accuracy_all_rgcn_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_rgcn_lr2_collapsed.index.values, mean_accuracy_all_rgcn_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_rgcn_lr3_collapsed.index.values, mean_accuracy_all_rgcn_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_rgcn_lr4_collapsed.index.values, mean_accuracy_all_rgcn_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_rgcn_lr1_collapsed.index.values, mean_accuracy_all_rgcn_lr1_collapsed - std_accuracy_all_rgcn_lr1_collapsed, mean_accuracy_all_rgcn_lr1_collapsed + std_accuracy_all_rgcn_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr2_collapsed.index.values, mean_accuracy_all_rgcn_lr2_collapsed - std_accuracy_all_rgcn_lr2_collapsed, mean_accuracy_all_rgcn_lr2_collapsed + std_accuracy_all_rgcn_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr3_collapsed.index.values, mean_accuracy_all_rgcn_lr3_collapsed - std_accuracy_all_rgcn_lr3_collapsed, mean_accuracy_all_rgcn_lr3_collapsed + std_accuracy_all_rgcn_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr4_collapsed.index.values, mean_accuracy_all_rgcn_lr4_collapsed - std_accuracy_all_rgcn_lr4_collapsed, mean_accuracy_all_rgcn_lr4_collapsed + std_accuracy_all_rgcn_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of R-GCN for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_collapsed_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_rgcn_lr1_collapsed.index.values, mean_loss_all_rgcn_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_rgcn_lr2_collapsed.index.values, mean_loss_all_rgcn_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_rgcn_lr3_collapsed.index.values, mean_loss_all_rgcn_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_rgcn_lr4_collapsed.index.values, mean_loss_all_rgcn_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_rgcn_lr1_collapsed.index.values, mean_loss_all_rgcn_lr1_collapsed - std_loss_all_rgcn_lr1_collapsed, mean_loss_all_rgcn_lr1_collapsed + std_loss_all_rgcn_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr2_collapsed.index.values, mean_loss_all_rgcn_lr2_collapsed - std_loss_all_rgcn_lr2_collapsed, mean_loss_all_rgcn_lr2_collapsed + std_loss_all_rgcn_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr3_collapsed.index.values, mean_loss_all_rgcn_lr3_collapsed - std_loss_all_rgcn_lr3_collapsed, mean_loss_all_rgcn_lr3_collapsed + std_loss_all_rgcn_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr4_collapsed.index.values, mean_loss_all_rgcn_lr4_collapsed - std_loss_all_rgcn_lr4_collapsed, mean_loss_all_rgcn_lr4_collapsed + std_loss_all_rgcn_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of R-GCN for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_collapsed_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gat_lr1_collapsed.index.values, mean_accuracy_all_gat_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gat_lr2_collapsed.index.values, mean_accuracy_all_gat_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gat_lr3_collapsed.index.values, mean_accuracy_all_gat_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gat_lr4_collapsed.index.values, mean_accuracy_all_gat_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gat_lr1_collapsed.index.values, mean_accuracy_all_gat_lr1_collapsed - std_accuracy_all_gat_lr1_collapsed, mean_accuracy_all_gat_lr1_collapsed + std_accuracy_all_gat_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr2_collapsed.index.values, mean_accuracy_all_gat_lr2_collapsed - std_accuracy_all_gat_lr2_collapsed, mean_accuracy_all_gat_lr2_collapsed + std_accuracy_all_gat_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr3_collapsed.index.values, mean_accuracy_all_gat_lr3_collapsed - std_accuracy_all_gat_lr3_collapsed, mean_accuracy_all_gat_lr3_collapsed + std_accuracy_all_gat_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr4_collapsed.index.values, mean_accuracy_all_gat_lr4_collapsed - std_accuracy_all_gat_lr4_collapsed, mean_accuracy_all_gat_lr4_collapsed + std_accuracy_all_gat_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GAT for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_collapsed_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gat_lr1_collapsed.index.values, mean_loss_all_gat_lr1_collapsed, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gat_lr2_collapsed.index.values, mean_loss_all_gat_lr2_collapsed, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gat_lr3_collapsed.index.values, mean_loss_all_gat_lr3_collapsed, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gat_lr4_collapsed.index.values, mean_loss_all_gat_lr4_collapsed, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gat_lr1_collapsed.index.values, mean_loss_all_gat_lr1_collapsed - std_loss_all_gat_lr1_collapsed, mean_loss_all_gat_lr1_collapsed + std_loss_all_gat_lr1_collapsed, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr2_collapsed.index.values, mean_loss_all_gat_lr2_collapsed - std_loss_all_gat_lr2_collapsed, mean_loss_all_gat_lr2_collapsed + std_loss_all_gat_lr2_collapsed, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr3_collapsed.index.values, mean_loss_all_gat_lr3_collapsed - std_loss_all_gat_lr3_collapsed, mean_loss_all_gat_lr3_collapsed + std_loss_all_gat_lr3_collapsed, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr4_collapsed.index.values, mean_loss_all_gat_lr4_collapsed - std_loss_all_gat_lr4_collapsed, mean_loss_all_gat_lr4_collapsed + std_loss_all_gat_lr4_collapsed, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GAT for Collapsed DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_collapsed_valloss.png', dpi=300)

plt.show()

# %% [markdown]
# ### Separate:

# %%
# concatenate all these results
# only for the reconstruction loss 
rec_loss_gae_lr1_separate = pd.concat([gae_lr1_s0_separate['ReconLossTrain'], gae_lr1_s1_separate['ReconLossTrain'], gae_lr1_s2_separate['ReconLossTrain']], axis=1)
rec_loss_gae_lr2_separate = pd.concat([gae_lr2_s0_separate['ReconLossTrain'], gae_lr2_s1_separate['ReconLossTrain'], gae_lr2_s2_separate['ReconLossTrain']], axis=1)
rec_loss_gae_lr3_separate = pd.concat([gae_lr3_s0_separate['ReconLossTrain'], gae_lr3_s1_separate['ReconLossTrain'], gae_lr3_s2_separate['ReconLossTrain']], axis=1)
rec_loss_gae_lr4_separate = pd.concat([gae_lr4_s0_separate['ReconLossTrain'], gae_lr4_s1_separate['ReconLossTrain'], gae_lr4_s2_separate['ReconLossTrain']], axis=1)

# ---- GCN ------
accuracy_all_gcn_lr1_separate = pd.concat([gcn_lr1_s0_separate['AccTest'], gcn_lr1_s1_separate['AccTest'], gcn_lr1_s2_separate['AccTest']], axis=1)
loss_all_gcn_lr1_separate = pd.concat([gcn_lr1_s0_separate['CrossEntropyLossTest'], gcn_lr1_s1_separate['CrossEntropyLossTest'], gcn_lr1_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr2_separate = pd.concat([gcn_lr2_s0_separate['AccTest'], gcn_lr2_s1_separate['AccTest'], gcn_lr2_s2_separate['AccTest']], axis=1)
loss_all_gcn_lr2_separate = pd.concat([gcn_lr2_s0_separate['CrossEntropyLossTest'], gcn_lr2_s1_separate['CrossEntropyLossTest'], gcn_lr2_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr3_separate = pd.concat([gcn_lr3_s0_separate['AccTest'], gcn_lr3_s1_separate['AccTest'], gcn_lr3_s2_separate['AccTest']], axis=1)
loss_all_gcn_lr3_separate = pd.concat([gcn_lr3_s0_separate['CrossEntropyLossTest'], gcn_lr3_s1_separate['CrossEntropyLossTest'], gcn_lr3_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gcn_lr4_separate = pd.concat([gcn_lr4_s0_separate['AccTest'], gcn_lr4_s1_separate['AccTest'], gcn_lr4_s2_separate['AccTest']], axis=1)
loss_all_gcn_lr4_separate = pd.concat([gcn_lr4_s0_separate['CrossEntropyLossTest'], gcn_lr4_s1_separate['CrossEntropyLossTest'], gcn_lr4_s2_separate['CrossEntropyLossTest']], axis=1)

# ---- RGCN ------
accuracy_all_rgcn_lr1_separate = pd.concat([rgcn_lr1_s0_separate['AccTest'], rgcn_lr1_s1_separate['AccTest'], rgcn_lr1_s2_separate['AccTest']], axis=1)
loss_all_rgcn_lr1_separate = pd.concat([rgcn_lr1_s0_separate['CrossEntropyLossTest'], rgcn_lr1_s1_separate['CrossEntropyLossTest'], rgcn_lr1_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr2_separate = pd.concat([rgcn_lr2_s0_separate['AccTest'], rgcn_lr2_s1_separate['AccTest'], rgcn_lr2_s2_separate['AccTest']], axis=1)
loss_all_rgcn_lr2_separate = pd.concat([rgcn_lr2_s0_separate['CrossEntropyLossTest'], rgcn_lr2_s1_separate['CrossEntropyLossTest'], rgcn_lr2_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr3_separate = pd.concat([rgcn_lr3_s0_separate['AccTest'], rgcn_lr3_s1_separate['AccTest'], rgcn_lr3_s2_separate['AccTest']], axis=1)
loss_all_rgcn_lr3_separate = pd.concat([rgcn_lr3_s0_separate['CrossEntropyLossTest'], rgcn_lr3_s1_separate['CrossEntropyLossTest'], rgcn_lr3_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_rgcn_lr4_separate = pd.concat([rgcn_lr4_s0_separate['AccTest'], rgcn_lr4_s1_separate['AccTest'], rgcn_lr4_s2_separate['AccTest']], axis=1)
loss_all_rgcn_lr4_separate = pd.concat([rgcn_lr4_s0_separate['CrossEntropyLossTest'], rgcn_lr4_s1_separate['CrossEntropyLossTest'], rgcn_lr4_s2_separate['CrossEntropyLossTest']], axis=1)

# ---- GAT ------
accuracy_all_gat_lr1_separate = pd.concat([gat_lr1_s0_separate['AccTest'], gat_lr1_s1_separate['AccTest'], gat_lr1_s2_separate['AccTest']], axis=1)
loss_all_gat_lr1_separate = pd.concat([gat_lr1_s0_separate['CrossEntropyLossTest'], gat_lr1_s1_separate['CrossEntropyLossTest'], gat_lr1_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr2_separate = pd.concat([gat_lr2_s0_separate['AccTest'], gat_lr2_s1_separate['AccTest'], gat_lr2_s2_separate['AccTest']], axis=1)
loss_all_gat_lr2_separate = pd.concat([gat_lr2_s0_separate['CrossEntropyLossTest'], gat_lr2_s1_separate['CrossEntropyLossTest'], gat_lr2_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr3_separate = pd.concat([gat_lr3_s0_separate['AccTest'], gat_lr3_s1_separate['AccTest'], gat_lr3_s2_separate['AccTest']], axis=1)
loss_all_gat_lr3_separate = pd.concat([gat_lr3_s0_separate['CrossEntropyLossTest'], gat_lr3_s1_separate['CrossEntropyLossTest'], gat_lr3_s2_separate['CrossEntropyLossTest']], axis=1)

accuracy_all_gat_lr4_separate = pd.concat([gat_lr4_s0_separate['AccTest'], gat_lr4_s1_separate['AccTest'], gat_lr4_s2_separate['AccTest']], axis=1)
loss_all_gat_lr4_separate = pd.concat([gat_lr4_s0_separate['CrossEntropyLossTest'], gat_lr4_s1_separate['CrossEntropyLossTest'], gat_lr4_s2_separate['CrossEntropyLossTest']], axis=1)

# %%
# get the mean and std of all these results!
# GCN
mean_accuracy_all_gcn_lr1_separate = accuracy_all_gcn_lr1_separate.mean(axis=1)
std_accuracy_all_gcn_lr1_separate = accuracy_all_gcn_lr1_separate.std(axis=1)

mean_accuracy_all_gcn_lr2_separate = accuracy_all_gcn_lr2_separate.mean(axis=1)
std_accuracy_all_gcn_lr2_separate= accuracy_all_gcn_lr2_separate.std(axis=1)

mean_accuracy_all_gcn_lr3_separate = accuracy_all_gcn_lr3_separate.mean(axis=1)
std_accuracy_all_gcn_lr3_separate = accuracy_all_gcn_lr3_separate.std(axis=1)

mean_accuracy_all_gcn_lr4_separate = accuracy_all_gcn_lr4_separate.mean(axis=1)
std_accuracy_all_gcn_lr4_separate = accuracy_all_gcn_lr4_separate.std(axis=1)

# RGCN
mean_accuracy_all_rgcn_lr1_separate = accuracy_all_rgcn_lr1_separate.mean(axis=1)
std_accuracy_all_rgcn_lr1_separate = accuracy_all_rgcn_lr1_separate.std(axis=1)

mean_accuracy_all_rgcn_lr2_separate = accuracy_all_rgcn_lr2_separate.mean(axis=1)
std_accuracy_all_rgcn_lr2_separate = accuracy_all_rgcn_lr2_separate.std(axis=1)

mean_accuracy_all_rgcn_lr3_separate = accuracy_all_rgcn_lr3_separate.mean(axis=1)
std_accuracy_all_rgcn_lr3_separate = accuracy_all_rgcn_lr3_separate.std(axis=1)

mean_accuracy_all_rgcn_lr4_separate = accuracy_all_rgcn_lr4_separate.mean(axis=1)
std_accuracy_all_rgcn_lr4_separate = accuracy_all_rgcn_lr4_separate.std(axis=1)

# GAT
mean_accuracy_all_gat_lr1_separate = accuracy_all_gat_lr1_separate.mean(axis=1)
std_accuracy_all_gat_lr1_separate = accuracy_all_gat_lr1_separate.std(axis=1)

mean_accuracy_all_gat_lr2_separate = accuracy_all_gat_lr2_separate.mean(axis=1)
std_accuracy_all_gat_lr2_separate = accuracy_all_gat_lr2_separate.std(axis=1)

mean_accuracy_all_gat_lr3_separate = accuracy_all_gat_lr3_separate.mean(axis=1)
std_accuracy_all_gat_lr3_separate = accuracy_all_gat_lr3_separate.std(axis=1)

mean_accuracy_all_gat_lr4_separate = accuracy_all_gat_lr4_separate.mean(axis=1)
std_accuracy_all_gat_lr4_separate = accuracy_all_gat_lr4_separate.std(axis=1)

# %%
# GAE
mean_rec_loss_gae_lr1_separate = rec_loss_gae_lr1_separate.mean(axis=1)
std_rec_loss_gae_lr1_separate = rec_loss_gae_lr1_separate.std(axis=1)

mean_rec_loss_gae_lr2_separate = rec_loss_gae_lr2_separate.mean(axis=1)
std_rec_loss_gae_lr2_separate = rec_loss_gae_lr2_separate.std(axis=1)

mean_rec_loss_gae_lr3_separate = rec_loss_gae_lr3_separate.mean(axis=1)
std_rec_loss_gae_lr3_separate = rec_loss_gae_lr3_separate.std(axis=1)

mean_rec_loss_gae_lr4_separate = rec_loss_gae_lr4_separate.mean(axis=1)
std_rec_loss_gae_lr4_separate = rec_loss_gae_lr4_separate.std(axis=1)

# GCN
mean_loss_all_gcn_lr1_separate = loss_all_gcn_lr1_separate.mean(axis=1)
std_loss_all_gcn_lr1_separate = loss_all_gcn_lr1_separate.std(axis=1)

mean_loss_all_gcn_lr2_separate = loss_all_gcn_lr2_separate.mean(axis=1)
std_loss_all_gcn_lr2_separate = loss_all_gcn_lr2_separate.std(axis=1)

mean_loss_all_gcn_lr3_separate = loss_all_gcn_lr3_separate.mean(axis=1)
std_loss_all_gcn_lr3_separate = loss_all_gcn_lr3_separate.std(axis=1)

mean_loss_all_gcn_lr4_separate = loss_all_gcn_lr4_separate.mean(axis=1)
std_loss_all_gcn_lr4_separate = loss_all_gcn_lr4_separate.std(axis=1)

# RGCN
mean_loss_all_rgcn_lr1_separate = loss_all_rgcn_lr1_separate.mean(axis=1)
std_loss_all_rgcn_lr1_separate = loss_all_rgcn_lr1_separate.std(axis=1)

mean_loss_all_rgcn_lr2_separate = loss_all_rgcn_lr2_separate.mean(axis=1)
std_loss_all_rgcn_lr2_separate = loss_all_rgcn_lr2_separate.std(axis=1)

mean_loss_all_rgcn_lr3_separate = loss_all_rgcn_lr3_separate.mean(axis=1)
std_loss_all_rgcn_lr3_separate = loss_all_rgcn_lr3_separate.std(axis=1)

mean_loss_all_rgcn_lr4_separate = loss_all_rgcn_lr4_separate.mean(axis=1)
std_loss_all_rgcn_lr4_separate = loss_all_rgcn_lr4_separate.std(axis=1)

# GAT
mean_loss_all_gat_lr1_separate = loss_all_gat_lr1_separate.mean(axis=1)
std_loss_all_gat_lr1_separate = loss_all_gat_lr1_separate.std(axis=1)

mean_loss_all_gat_lr2_separate = loss_all_gat_lr2_separate.mean(axis=1)
std_loss_all_gat_lr2_separate = loss_all_gat_lr2_separate.std(axis=1)

mean_loss_all_gat_lr3_separate = loss_all_gat_lr3_separate.mean(axis=1)
std_loss_all_gat_lr3_separate = loss_all_gat_lr3_separate.std(axis=1)

mean_loss_all_gat_lr4_separate = loss_all_gat_lr4_separate.mean(axis=1)
std_loss_all_gat_lr4_separate = loss_all_gat_lr4_separate.std(axis=1)

# %%
# draw the lines for the means
plt.plot(mean_rec_loss_gae_lr1_separate.index.values, mean_rec_loss_gae_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_rec_loss_gae_lr2_separate.index.values, mean_rec_loss_gae_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_rec_loss_gae_lr3_separate.index.values, mean_rec_loss_gae_lr3_separate, 'b-', label='Learning Rate: 0.01')
#plt.plot(mean_rec_loss_gae_lr4_separate.index.values, mean_rec_loss_gae_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_rec_loss_gae_lr1_separate.index.values, mean_rec_loss_gae_lr1_separate - std_rec_loss_gae_lr1_separate, mean_rec_loss_gae_lr1_separate + std_rec_loss_gae_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr2_separate.index.values, mean_rec_loss_gae_lr2_separate - std_rec_loss_gae_lr2_separate, mean_rec_loss_gae_lr2_separate + std_rec_loss_gae_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_rec_loss_gae_lr3_separate.index.values, mean_rec_loss_gae_lr3_separate - std_rec_loss_gae_lr3_separate, mean_rec_loss_gae_lr3_separate + std_rec_loss_gae_lr3_separate, color='b', alpha=0.25)
#plt.fill_between(std_rec_loss_gae_lr4_separate.index.values, mean_rec_loss_gae_lr4_separate - std_rec_loss_gae_lr4_separate, mean_rec_loss_gae_lr4_separate + std_rec_loss_gae_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Reconstruction Loss of GAE for Seprate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Reconstruction Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gae_separate_rec_loss.png', dpi=300)

plt.show()

# %%
# adj rand
gae_lr1_separate_adj_rand_mean = mean([gae_lr1_s0_separate_final['Rand12'][0], gae_lr1_s0_separate_final['Rand23'][0], gae_lr1_s0_separate_final['Rand13'][0], gae_lr1_s1_separate_final['Rand12'][0], gae_lr1_s1_separate_final['Rand23'][0], gae_lr1_s1_separate_final['Rand13'][0], gae_lr1_s2_separate_final['Rand12'][0], gae_lr1_s2_separate_final['Rand23'][0], gae_lr1_s2_separate_final['Rand13'][0]])
gae_lr1_separate_adj_rand_std = std([gae_lr1_s0_separate_final['Rand12'][0], gae_lr1_s0_separate_final['Rand23'][0], gae_lr1_s0_separate_final['Rand13'][0], gae_lr1_s1_separate_final['Rand12'][0], gae_lr1_s1_separate_final['Rand23'][0], gae_lr1_s1_separate_final['Rand13'][0], gae_lr1_s2_separate_final['Rand12'][0], gae_lr1_s2_separate_final['Rand23'][0], gae_lr1_s2_separate_final['Rand13'][0]])

gae_lr2_separate_adj_rand_mean = mean([gae_lr2_s0_separate_final['Rand12'][0], gae_lr2_s0_separate_final['Rand23'][0], gae_lr2_s0_separate_final['Rand13'][0], gae_lr2_s1_separate_final['Rand12'][0], gae_lr2_s1_separate_final['Rand23'][0], gae_lr2_s1_separate_final['Rand13'][0], gae_lr2_s2_separate_final['Rand12'][0], gae_lr2_s2_separate_final['Rand23'][0], gae_lr2_s2_separate_final['Rand13'][0]])
gae_lr2_separate_adj_rand_std = std([gae_lr2_s0_separate_final['Rand12'][0], gae_lr2_s0_separate_final['Rand23'][0], gae_lr2_s0_separate_final['Rand13'][0], gae_lr2_s1_separate_final['Rand12'][0], gae_lr2_s1_separate_final['Rand23'][0], gae_lr2_s1_separate_final['Rand13'][0], gae_lr2_s2_separate_final['Rand12'][0], gae_lr2_s2_separate_final['Rand23'][0], gae_lr2_s2_separate_final['Rand13'][0]])

gae_lr3_separate_adj_rand_mean = mean([gae_lr3_s0_separate_final['Rand12'][0], gae_lr3_s0_separate_final['Rand23'][0], gae_lr3_s0_separate_final['Rand13'][0], gae_lr3_s1_separate_final['Rand12'][0], gae_lr3_s1_separate_final['Rand23'][0], gae_lr3_s1_separate_final['Rand13'][0], gae_lr3_s2_separate_final['Rand12'][0], gae_lr3_s2_separate_final['Rand23'][0], gae_lr3_s2_separate_final['Rand13'][0]])
gae_lr3_separate_adj_rand_std = std([gae_lr3_s0_separate_final['Rand12'][0], gae_lr3_s0_separate_final['Rand23'][0], gae_lr3_s0_separate_final['Rand13'][0], gae_lr3_s1_separate_final['Rand12'][0], gae_lr3_s1_separate_final['Rand23'][0], gae_lr3_s1_separate_final['Rand13'][0], gae_lr3_s2_separate_final['Rand12'][0], gae_lr3_s2_separate_final['Rand23'][0], gae_lr3_s2_separate_final['Rand13'][0]])

gae_lr4_separate_adj_rand_mean = mean([gae_lr4_s0_separate_final['Rand12'][0], gae_lr4_s0_separate_final['Rand23'][0], gae_lr4_s0_separate_final['Rand13'][0], gae_lr4_s1_separate_final['Rand12'][0], gae_lr4_s1_separate_final['Rand23'][0], gae_lr4_s1_separate_final['Rand13'][0], gae_lr4_s2_separate_final['Rand12'][0], gae_lr4_s2_separate_final['Rand23'][0], gae_lr4_s2_separate_final['Rand13'][0]])
gae_lr4_separate_adj_rand_std = std([gae_lr4_s0_separate_final['Rand12'][0], gae_lr4_s0_separate_final['Rand23'][0], gae_lr4_s0_separate_final['Rand13'][0], gae_lr4_s1_separate_final['Rand12'][0], gae_lr4_s1_separate_final['Rand23'][0], gae_lr4_s1_separate_final['Rand13'][0], gae_lr4_s2_separate_final['Rand12'][0], gae_lr4_s2_separate_final['Rand23'][0], gae_lr4_s2_separate_final['Rand13'][0]])

# bic score
gae_lr1_separate_bic_mean = mean([gae_lr1_s0_separate_final['BIC_1'][0], gae_lr1_s0_separate_final['BIC_2'][0], gae_lr1_s0_separate_final['BIC_3'][0], gae_lr1_s1_separate_final['BIC_1'][0], gae_lr1_s1_separate_final['BIC_2'][0], gae_lr1_s1_separate_final['BIC_3'][0], gae_lr1_s2_separate_final['BIC_1'][0], gae_lr1_s2_separate_final['BIC_2'][0], gae_lr1_s2_separate_final['BIC_3'][0]])
gae_lr1_separate_bic_std = std([gae_lr1_s0_separate_final['BIC_1'][0], gae_lr1_s0_separate_final['BIC_2'][0], gae_lr1_s0_separate_final['BIC_3'][0], gae_lr1_s1_separate_final['BIC_1'][0], gae_lr1_s1_separate_final['BIC_2'][0], gae_lr1_s1_separate_final['BIC_3'][0], gae_lr1_s2_separate_final['BIC_1'][0], gae_lr1_s2_separate_final['BIC_2'][0], gae_lr1_s2_separate_final['BIC_3'][0]])

gae_lr2_separate_bic_mean = mean([gae_lr2_s0_separate_final['BIC_1'][0], gae_lr2_s0_separate_final['BIC_2'][0], gae_lr2_s0_separate_final['BIC_3'][0], gae_lr2_s1_separate_final['BIC_1'][0], gae_lr2_s1_separate_final['BIC_2'][0], gae_lr2_s1_separate_final['BIC_3'][0], gae_lr2_s2_separate_final['BIC_1'][0], gae_lr2_s2_separate_final['BIC_2'][0], gae_lr2_s2_separate_final['BIC_3'][0]])
gae_lr2_separate_bic_std = std([gae_lr2_s0_separate_final['BIC_1'][0], gae_lr2_s0_separate_final['BIC_2'][0], gae_lr2_s0_separate_final['BIC_3'][0], gae_lr2_s1_separate_final['BIC_1'][0], gae_lr2_s1_separate_final['BIC_2'][0], gae_lr2_s1_separate_final['BIC_3'][0], gae_lr2_s2_separate_final['BIC_1'][0], gae_lr2_s2_separate_final['BIC_2'][0], gae_lr2_s2_separate_final['BIC_3'][0]])

gae_lr3_separate_bic_mean = mean([gae_lr3_s0_separate_final['BIC_1'][0], gae_lr3_s0_separate_final['BIC_2'][0], gae_lr3_s0_separate_final['BIC_3'][0], gae_lr3_s1_separate_final['BIC_1'][0], gae_lr3_s1_separate_final['BIC_2'][0], gae_lr3_s1_separate_final['BIC_3'][0], gae_lr3_s2_separate_final['BIC_1'][0], gae_lr3_s2_separate_final['BIC_2'][0], gae_lr3_s2_separate_final['BIC_3'][0]])
gae_lr3_separate_bic_std = std([gae_lr3_s0_separate_final['BIC_1'][0], gae_lr3_s0_separate_final['BIC_2'][0], gae_lr3_s0_separate_final['BIC_3'][0], gae_lr3_s1_separate_final['BIC_1'][0], gae_lr3_s1_separate_final['BIC_2'][0], gae_lr3_s1_separate_final['BIC_3'][0], gae_lr3_s2_separate_final['BIC_1'][0], gae_lr3_s2_separate_final['BIC_2'][0], gae_lr3_s2_separate_final['BIC_3'][0]])

gae_lr4_separate_bic_mean = mean([gae_lr4_s0_separate_final['BIC_1'][0], gae_lr4_s0_separate_final['BIC_2'][0], gae_lr4_s0_separate_final['BIC_3'][0], gae_lr4_s1_separate_final['BIC_1'][0], gae_lr4_s1_separate_final['BIC_2'][0], gae_lr4_s1_separate_final['BIC_3'][0], gae_lr4_s2_separate_final['BIC_1'][0], gae_lr4_s2_separate_final['BIC_2'][0], gae_lr4_s2_separate_final['BIC_3'][0]])
gae_lr4_separate_bic_std = std([gae_lr4_s0_separate_final['BIC_1'][0], gae_lr4_s0_separate_final['BIC_2'][0], gae_lr4_s0_separate_final['BIC_3'][0], gae_lr4_s1_separate_final['BIC_1'][0], gae_lr4_s1_separate_final['BIC_2'][0], gae_lr4_s1_separate_final['BIC_3'][0], gae_lr4_s2_separate_final['BIC_1'][0], gae_lr4_s2_separate_final['BIC_2'][0], gae_lr4_s2_separate_final['BIC_3'][0]])

# print results
print("Learning rate 0.001: Adj. Rand. Mean: ",gae_lr1_separate_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr1_separate_adj_rand_std, ", BIC Mean: ", gae_lr1_separate_bic_mean, ", BIC Std: ", gae_lr1_separate_bic_std)
print("Learning rate 0.005: Adj. Rand. Mean: ",gae_lr2_separate_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr2_separate_adj_rand_std, ", BIC Mean: ", gae_lr2_separate_bic_mean, ", BIC Std: ", gae_lr2_separate_bic_std)
print("Learning rate 0.01: Adj. Rand. Mean: ",gae_lr3_separate_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr3_separate_adj_rand_std, ", BIC Mean: ", gae_lr3_separate_bic_mean, ", BIC Std: ", gae_lr3_separate_bic_std)
print("Learning rate 0.1: Adj. Rand. Mean: ",gae_lr4_separate_adj_rand_mean, ", Adj. Rand. Std.: ", gae_lr4_separate_adj_rand_std, ", BIC Mean: ", gae_lr4_separate_bic_mean, ", BIC Std: ", gae_lr4_separate_bic_std)
# Out:
# Learning rate 0.001: Adj. Rand. Mean:  0.9224422831213189 , Adj. Rand. Std.:  0.04904047584884007 , BIC Mean:  1038571.8498612784 , BIC Std:  65998.79536153172
# Learning rate 0.005: Adj. Rand. Mean:  0.9130333886643799 , Adj. Rand. Std.:  0.14644180799841883 , BIC Mean:  1081646.981782142 , BIC Std:  46261.0693850796
# Learning rate 0.01: Adj. Rand. Mean:  0.8450785569537608 , Adj. Rand. Std.:  0.30585851958041826 , BIC Mean:  -4711883.511367337 , BIC Std:  4252117.25403204
# Learning rate 0.1: Adj. Rand. Mean:  0.7500400639332865 , Adj. Rand. Std.:  0.41100889368306665 , BIC Mean:  4618410.925267861 , BIC Std:  1822520.1406095834

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gcn_lr1_separate.index.values, mean_accuracy_all_gcn_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gcn_lr2_separate.index.values, mean_accuracy_all_gcn_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gcn_lr3_separate.index.values, mean_accuracy_all_gcn_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gcn_lr4_separate.index.values, mean_accuracy_all_gcn_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gcn_lr1_separate.index.values, mean_accuracy_all_gcn_lr1_separate - std_accuracy_all_gcn_lr1_separate, mean_accuracy_all_gcn_lr1_separate + std_accuracy_all_gcn_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr2_separate.index.values, mean_accuracy_all_gcn_lr2_separate - std_accuracy_all_gcn_lr2_separate, mean_accuracy_all_gcn_lr2_separate + std_accuracy_all_gcn_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr3_separate.index.values, mean_accuracy_all_gcn_lr3_separate - std_accuracy_all_gcn_lr3_separate, mean_accuracy_all_gcn_lr3_separate + std_accuracy_all_gcn_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gcn_lr4_separate.index.values, mean_accuracy_all_gcn_lr4_separate - std_accuracy_all_gcn_lr4_separate, mean_accuracy_all_gcn_lr4_separate + std_accuracy_all_gcn_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GCN for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_separate_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gcn_lr1_separate.index.values, mean_loss_all_gcn_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gcn_lr2_separate.index.values, mean_loss_all_gcn_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gcn_lr3_separate.index.values, mean_loss_all_gcn_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gcn_lr4_separate.index.values, mean_loss_all_gcn_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gcn_lr1_separate.index.values, mean_loss_all_gcn_lr1_separate - std_loss_all_gcn_lr1_separate, mean_loss_all_gcn_lr1_separate + std_loss_all_gcn_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr2_separate.index.values, mean_loss_all_gcn_lr2_separate - std_loss_all_gcn_lr2_separate, mean_loss_all_gcn_lr2_separate + std_loss_all_gcn_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr3_separate.index.values, mean_loss_all_gcn_lr3_separate - std_loss_all_gcn_lr3_separate, mean_loss_all_gcn_lr3_separate + std_loss_all_gcn_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gcn_lr4_separate.index.values, mean_loss_all_gcn_lr4_separate - std_loss_all_gcn_lr4_separate, mean_loss_all_gcn_lr4_separate + std_loss_all_gcn_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GCN for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gcn_separate_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_rgcn_lr1_separate.index.values, mean_accuracy_all_rgcn_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_rgcn_lr2_separate.index.values, mean_accuracy_all_rgcn_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_rgcn_lr3_separate.index.values, mean_accuracy_all_rgcn_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_rgcn_lr4_separate.index.values, mean_accuracy_all_rgcn_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_rgcn_lr1_separate.index.values, mean_accuracy_all_rgcn_lr1_separate - std_accuracy_all_rgcn_lr1_separate, mean_accuracy_all_rgcn_lr1_separate + std_accuracy_all_rgcn_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr2_separate.index.values, mean_accuracy_all_rgcn_lr2_separate - std_accuracy_all_rgcn_lr2_separate, mean_accuracy_all_rgcn_lr2_separate + std_accuracy_all_rgcn_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr3_separate.index.values, mean_accuracy_all_rgcn_lr3_separate - std_accuracy_all_rgcn_lr3_separate, mean_accuracy_all_rgcn_lr3_separate + std_accuracy_all_rgcn_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_rgcn_lr4_separate.index.values, mean_accuracy_all_rgcn_lr4_separate - std_accuracy_all_rgcn_lr4_separate, mean_accuracy_all_rgcn_lr4_separate + std_accuracy_all_rgcn_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of R-GCN for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_separate_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_rgcn_lr1_separate.index.values, mean_loss_all_rgcn_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_rgcn_lr2_separate.index.values, mean_loss_all_rgcn_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_rgcn_lr3_separate.index.values, mean_loss_all_rgcn_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_rgcn_lr4_separate.index.values, mean_loss_all_rgcn_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_rgcn_lr1_separate.index.values, mean_loss_all_rgcn_lr1_separate - std_loss_all_rgcn_lr1_separate, mean_loss_all_rgcn_lr1_separate + std_loss_all_rgcn_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr2_separate.index.values, mean_loss_all_rgcn_lr2_separate - std_loss_all_rgcn_lr2_separate, mean_loss_all_rgcn_lr2_separate + std_loss_all_rgcn_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr3_separate.index.values, mean_loss_all_rgcn_lr3_separate - std_loss_all_rgcn_lr3_separate, mean_loss_all_rgcn_lr3_separate + std_loss_all_rgcn_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_loss_all_rgcn_lr4_separate.index.values, mean_loss_all_rgcn_lr4_separate - std_loss_all_rgcn_lr4_separate, mean_loss_all_rgcn_lr4_separate + std_loss_all_rgcn_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of R-GCN for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/rgcn_separate_valloss.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_accuracy_all_gat_lr1_separate.index.values, mean_accuracy_all_gat_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_accuracy_all_gat_lr2_separate.index.values, mean_accuracy_all_gat_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_accuracy_all_gat_lr3_separate.index.values, mean_accuracy_all_gat_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_accuracy_all_gat_lr4_separate.index.values, mean_accuracy_all_gat_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_accuracy_all_gat_lr1_separate.index.values, mean_accuracy_all_gat_lr1_separate - std_accuracy_all_gat_lr1_separate, mean_accuracy_all_gat_lr1_separate + std_accuracy_all_gat_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr2_separate.index.values, mean_accuracy_all_gat_lr2_separate - std_accuracy_all_gat_lr2_separate, mean_accuracy_all_gat_lr2_separate + std_accuracy_all_gat_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr3_separate.index.values, mean_accuracy_all_gat_lr3_separate - std_accuracy_all_gat_lr3_separate, mean_accuracy_all_gat_lr3_separate + std_accuracy_all_gat_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_accuracy_all_gat_lr4_separate.index.values, mean_accuracy_all_gat_lr4_separate - std_accuracy_all_gat_lr4_separate, mean_accuracy_all_gat_lr4_separate + std_accuracy_all_gat_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
plt.title("Validation Accuracy of GAT for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_separate_valacc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_loss_all_gat_lr1_separate.index.values, mean_loss_all_gat_lr1_separate, 'y-', label='Learning Rate: 0.001')
plt.plot(mean_loss_all_gat_lr2_separate.index.values, mean_loss_all_gat_lr2_separate, 'r-', label='Learning Rate: 0.005')
plt.plot(mean_loss_all_gat_lr3_separate.index.values, mean_loss_all_gat_lr3_separate, 'b-', label='Learning Rate: 0.01')
plt.plot(mean_loss_all_gat_lr4_separate.index.values, mean_loss_all_gat_lr4_separate, 'g-', label='Learning Rate: 0.1')

# fill between the standard deviations
plt.fill_between(std_loss_all_gat_lr1_separate.index.values, mean_loss_all_gat_lr1_separate - std_loss_all_gat_lr1_separate, mean_loss_all_gat_lr1_separate + std_loss_all_gat_lr1_separate, color='y', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr2_separate.index.values, mean_loss_all_gat_lr2_separate - std_loss_all_gat_lr2_separate, mean_loss_all_gat_lr2_separate + std_loss_all_gat_lr2_separate, color='r', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr3_separate.index.values, mean_loss_all_gat_lr3_separate - std_loss_all_gat_lr3_separate, mean_loss_all_gat_lr3_separate + std_loss_all_gat_lr3_separate, color='b', alpha=0.25)
plt.fill_between(std_loss_all_gat_lr4_separate.index.values, mean_loss_all_gat_lr4_separate - std_loss_all_gat_lr4_separate, mean_loss_all_gat_lr4_separate + std_loss_all_gat_lr4_separate, color='g', alpha=0.25)

plt.legend(loc="upper right", fontsize=21)
plt.title("Validation Loss of GAT for Separate DMG777k Dataset with Different Learning Rates", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Validation Loss', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/hyperparameter_optimization/dmg777k/gat_separate_valloss.png', dpi=300)

plt.show()
