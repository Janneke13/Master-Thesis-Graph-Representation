# %% [markdown]
# # Data Analysis of the AIFB+ experiment data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read in the data:

# %% [markdown]
# ### GAE

# %% [markdown]
# ### GCN

# %%
results_gcn_filtered_1 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_1/results.csv")
results_gcn_filtered_2 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_2/results.csv")
results_gcn_filtered_3 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_3/results.csv")
results_gcn_filtered_4 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_4/results.csv")
results_gcn_filtered_5 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_5/results.csv")
results_gcn_filtered_6 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_6/results.csv")
results_gcn_filtered_7 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_7/results.csv")
results_gcn_filtered_8 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_8/results.csv")
results_gcn_filtered_9 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_9/results.csv")
results_gcn_filtered_10 = pd.read_csv("../results/GCN/test_aifb_filtered_inverse/aifb_10/results.csv")

results_gcn_alltoone_1 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_1/results.csv")
results_gcn_alltoone_2 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_2/results.csv")
results_gcn_alltoone_3 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_3/results.csv")
results_gcn_alltoone_4 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_4/results.csv")
results_gcn_alltoone_5 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_5/results.csv")
results_gcn_alltoone_6 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_6/results.csv")
results_gcn_alltoone_7 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_7/results.csv")
results_gcn_alltoone_8 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_8/results.csv")
results_gcn_alltoone_9 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_9/results.csv")
results_gcn_alltoone_10 = pd.read_csv("../results/GCN/test_aifb_alltoone_inverse/aifb_10/results.csv")

results_gcn_collapsed_1 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_1/results.csv")
results_gcn_collapsed_2 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_2/results.csv")
results_gcn_collapsed_3 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_3/results.csv")
results_gcn_collapsed_4 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_4/results.csv")
results_gcn_collapsed_5 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_5/results.csv")
results_gcn_collapsed_6 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_6/results.csv")
results_gcn_collapsed_7 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_7/results.csv")
results_gcn_collapsed_8 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_8/results.csv")
results_gcn_collapsed_9 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_9/results.csv")
results_gcn_collapsed_10 = pd.read_csv("../results/GCN/test_aifb_collapsed_inverse/aifb_10/results.csv")

results_gcn_separate_1 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_1/results.csv")
results_gcn_separate_2 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_2/results.csv")
results_gcn_separate_3 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_3/results.csv")
results_gcn_separate_4 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_4/results.csv")
results_gcn_separate_5 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_5/results.csv")
results_gcn_separate_6 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_6/results.csv")
results_gcn_separate_7 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_7/results.csv")
results_gcn_separate_8 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_8/results.csv")
results_gcn_separate_9 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_9/results.csv")
results_gcn_separate_10 = pd.read_csv("../results/GCN/test_aifb_separate_inverse/aifb_10/results.csv")

# %% [markdown]
# ### RGCN

# %%
results_rgcn_filtered_1 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_1/results.csv")
results_rgcn_filtered_2 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_2/results.csv")
results_rgcn_filtered_3 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_3/results.csv")
results_rgcn_filtered_4 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_4/results.csv")
results_rgcn_filtered_5 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_5/results.csv")
results_rgcn_filtered_6 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_6/results.csv")
results_rgcn_filtered_7 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_7/results.csv")
results_rgcn_filtered_8 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_8/results.csv")
results_rgcn_filtered_9 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_9/results.csv")
results_rgcn_filtered_10 = pd.read_csv("../results/RGCN/test_aifb_filtered_inverse/aifb_10/results.csv")

results_rgcn_alltoone_1 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_1/results.csv")
results_rgcn_alltoone_2 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_2/results.csv")
results_rgcn_alltoone_3 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_3/results.csv")
results_rgcn_alltoone_4 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_4/results.csv")
results_rgcn_alltoone_5 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_5/results.csv")
results_rgcn_alltoone_6 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_6/results.csv")
results_rgcn_alltoone_7 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_7/results.csv")
results_rgcn_alltoone_8 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_8/results.csv")
results_rgcn_alltoone_9 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_9/results.csv")
results_rgcn_alltoone_10 = pd.read_csv("../results/RGCN/test_aifb_alltoone_inverse/aifb_10/results.csv")

results_rgcn_collapsed_1 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_1/results.csv")
results_rgcn_collapsed_2 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_2/results.csv")
results_rgcn_collapsed_3 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_3/results.csv")
results_rgcn_collapsed_4 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_4/results.csv")
results_rgcn_collapsed_5 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_5/results.csv")
results_rgcn_collapsed_6 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_6/results.csv")
results_rgcn_collapsed_7 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_7/results.csv")
results_rgcn_collapsed_8 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_8/results.csv")
results_rgcn_collapsed_9 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_9/results.csv")
results_rgcn_collapsed_10 = pd.read_csv("../results/RGCN/test_aifb_collapsed_inverse/aifb_10/results.csv")

results_rgcn_separate_1 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_1/results.csv")
results_rgcn_separate_2 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_2/results.csv")
results_rgcn_separate_3 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_3/results.csv")
results_rgcn_separate_4 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_4/results.csv")
results_rgcn_separate_5 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_5/results.csv")
results_rgcn_separate_6 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_6/results.csv")
results_rgcn_separate_7 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_7/results.csv")
results_rgcn_separate_8 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_8/results.csv")
results_rgcn_separate_9 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_9/results.csv")
results_rgcn_separate_10 = pd.read_csv("../results/RGCN/test_aifb_separate_inverse/aifb_10/results.csv")

# %% [markdown]
# ### GAT

# %%
results_gat_filtered_1 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_1/results.csv")
results_gat_filtered_2 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_2/results.csv")
results_gat_filtered_3 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_3/results.csv")
results_gat_filtered_4 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_4/results.csv")
results_gat_filtered_5 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_5/results.csv")
results_gat_filtered_6 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_6/results.csv")
results_gat_filtered_7 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_7/results.csv")
results_gat_filtered_8 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_8/results.csv")
results_gat_filtered_9 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_9/results.csv")
results_gat_filtered_10 = pd.read_csv("../results/GAT/test_aifb_filtered_inverse/aifb_10/results.csv")

results_gat_alltoone_1 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_1/results.csv")
results_gat_alltoone_2 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_2/results.csv")
results_gat_alltoone_3 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_3/results.csv")
results_gat_alltoone_4 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_4/results.csv")
results_gat_alltoone_5 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_5/results.csv")
results_gat_alltoone_6 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_6/results.csv")
results_gat_alltoone_7 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_7/results.csv")
results_gat_alltoone_8 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_8/results.csv")
results_gat_alltoone_9 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_9/results.csv")
results_gat_alltoone_10 = pd.read_csv("../results/GAT/test_aifb_alltoone_inverse/aifb_10/results.csv")

results_gat_collapsed_1 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_1/results.csv")
results_gat_collapsed_2 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_2/results.csv")
results_gat_collapsed_3 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_3/results.csv")
results_gat_collapsed_4 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_4/results.csv")
results_gat_collapsed_5 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_5/results.csv")
results_gat_collapsed_6 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_6/results.csv")
results_gat_collapsed_7 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_7/results.csv")
results_gat_collapsed_8 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_8/results.csv")
results_gat_collapsed_9 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_9/results.csv")
results_gat_collapsed_10 = pd.read_csv("../results/GAT/test_aifb_collapsed_inverse/aifb_10/results.csv")

results_gat_separate_1 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_1/results.csv")
results_gat_separate_2 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_2/results.csv")
results_gat_separate_3 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_3/results.csv")
results_gat_separate_4 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_4/results.csv")
results_gat_separate_5 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_5/results.csv")
results_gat_separate_6 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_6/results.csv")
results_gat_separate_7 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_7/results.csv")
results_gat_separate_8 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_8/results.csv")
results_gat_separate_9 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_9/results.csv")
results_gat_separate_10 = pd.read_csv("../results/GAT/test_aifb_separate_inverse/aifb_10/results.csv")

# %% [markdown]
# ## Process the data:

# %% [markdown]
# ### GAE:

# %% [markdown]
# ### GCN:

# %%
# combine the test accuracies
accuracy_test_gcn_filtered = pd.concat([results_gcn_filtered_1['AccTest'], results_gcn_filtered_2['AccTest'], results_gcn_filtered_3['AccTest'], results_gcn_filtered_4['AccTest'], results_gcn_filtered_5['AccTest'],results_gcn_filtered_6['AccTest'], results_gcn_filtered_7['AccTest'], results_gcn_filtered_8['AccTest'], results_gcn_filtered_9['AccTest'], results_gcn_filtered_10['AccTest']],axis=1)
accuracy_test_gcn_alltoone = pd.concat([results_gcn_alltoone_1['AccTest'], results_gcn_alltoone_2['AccTest'], results_gcn_alltoone_3['AccTest'], results_gcn_alltoone_4['AccTest'], results_gcn_alltoone_5['AccTest'],results_gcn_alltoone_6['AccTest'], results_gcn_alltoone_7['AccTest'], results_gcn_alltoone_8['AccTest'], results_gcn_alltoone_9['AccTest'], results_gcn_alltoone_10['AccTest']],axis=1)
accuracy_test_gcn_collapsed = pd.concat([results_gcn_collapsed_1['AccTest'], results_gcn_collapsed_2['AccTest'], results_gcn_collapsed_3['AccTest'], results_gcn_collapsed_4['AccTest'], results_gcn_collapsed_5['AccTest'],results_gcn_collapsed_6['AccTest'], results_gcn_collapsed_7['AccTest'], results_gcn_collapsed_8['AccTest'], results_gcn_collapsed_9['AccTest'], results_gcn_collapsed_10['AccTest']],axis=1)
accuracy_test_gcn_separate = pd.concat([results_gcn_separate_1['AccTest'], results_gcn_separate_2['AccTest'], results_gcn_separate_3['AccTest'], results_gcn_separate_4['AccTest'], results_gcn_separate_5['AccTest'],results_gcn_separate_6['AccTest'], results_gcn_separate_7['AccTest'], results_gcn_separate_8['AccTest'], results_gcn_separate_9['AccTest'], results_gcn_separate_10['AccTest']],axis=1)

# make lists of the final test accuracies
final_accuracy_test_gcn_filtered = [results_gcn_filtered_1['AccTest'].iloc[-1], results_gcn_filtered_2['AccTest'].iloc[-1], results_gcn_filtered_3['AccTest'].iloc[-1], results_gcn_filtered_4['AccTest'].iloc[-1], results_gcn_filtered_5['AccTest'].iloc[-1],results_gcn_filtered_6['AccTest'].iloc[-1], results_gcn_filtered_7['AccTest'].iloc[-1], results_gcn_filtered_8['AccTest'].iloc[-1], results_gcn_filtered_9['AccTest'].iloc[-1], results_gcn_filtered_10['AccTest'].iloc[-1]]
final_accuracy_test_gcn_alltoone = [results_gcn_alltoone_1['AccTest'].iloc[-1], results_gcn_alltoone_2['AccTest'].iloc[-1], results_gcn_alltoone_3['AccTest'].iloc[-1], results_gcn_alltoone_4['AccTest'].iloc[-1], results_gcn_alltoone_5['AccTest'].iloc[-1],results_gcn_alltoone_6['AccTest'].iloc[-1], results_gcn_alltoone_7['AccTest'].iloc[-1], results_gcn_alltoone_8['AccTest'].iloc[-1], results_gcn_alltoone_9['AccTest'].iloc[-1], results_gcn_alltoone_10['AccTest'].iloc[-1]]
final_accuracy_test_gcn_collapsed = [results_gcn_collapsed_1['AccTest'].iloc[-1], results_gcn_collapsed_2['AccTest'].iloc[-1], results_gcn_collapsed_3['AccTest'].iloc[-1], results_gcn_collapsed_4['AccTest'].iloc[-1], results_gcn_collapsed_5['AccTest'].iloc[-1],results_gcn_collapsed_6['AccTest'].iloc[-1], results_gcn_collapsed_7['AccTest'].iloc[-1], results_gcn_collapsed_8['AccTest'].iloc[-1], results_gcn_collapsed_9['AccTest'].iloc[-1], results_gcn_collapsed_10['AccTest'].iloc[-1]]
final_accuracy_test_gcn_separate = [results_gcn_separate_1['AccTest'].iloc[-1], results_gcn_separate_2['AccTest'].iloc[-1], results_gcn_separate_3['AccTest'].iloc[-1], results_gcn_separate_4['AccTest'].iloc[-1], results_gcn_separate_5['AccTest'].iloc[-1],results_gcn_separate_6['AccTest'].iloc[-1], results_gcn_separate_7['AccTest'].iloc[-1], results_gcn_separate_8['AccTest'].iloc[-1], results_gcn_separate_9['AccTest'].iloc[-1], results_gcn_separate_10['AccTest'].iloc[-1]]

# combine the test f1
f1_test_gcn_filtered = pd.concat([results_gcn_filtered_1['f1Test'], results_gcn_filtered_2['f1Test'], results_gcn_filtered_3['f1Test'], results_gcn_filtered_4['f1Test'], results_gcn_filtered_5['f1Test'],results_gcn_filtered_6['f1Test'], results_gcn_filtered_7['f1Test'], results_gcn_filtered_8['f1Test'], results_gcn_filtered_9['f1Test'], results_gcn_filtered_10['f1Test']],axis=1)
f1_test_gcn_alltoone = pd.concat([results_gcn_alltoone_1['f1Test'], results_gcn_alltoone_2['f1Test'], results_gcn_alltoone_3['f1Test'], results_gcn_alltoone_4['f1Test'], results_gcn_alltoone_5['f1Test'],results_gcn_alltoone_6['f1Test'], results_gcn_alltoone_7['f1Test'], results_gcn_alltoone_8['f1Test'], results_gcn_alltoone_9['f1Test'], results_gcn_alltoone_10['f1Test']],axis=1)
f1_test_gcn_collapsed = pd.concat([results_gcn_collapsed_1['f1Test'], results_gcn_collapsed_2['f1Test'], results_gcn_collapsed_3['f1Test'], results_gcn_collapsed_4['f1Test'], results_gcn_collapsed_5['f1Test'],results_gcn_collapsed_6['f1Test'], results_gcn_collapsed_7['f1Test'], results_gcn_collapsed_8['f1Test'], results_gcn_collapsed_9['f1Test'], results_gcn_collapsed_10['f1Test']],axis=1)
f1_test_gcn_separate = pd.concat([results_gcn_separate_1['f1Test'], results_gcn_separate_2['f1Test'], results_gcn_separate_3['f1Test'], results_gcn_separate_4['f1Test'], results_gcn_separate_5['f1Test'],results_gcn_separate_6['f1Test'], results_gcn_separate_7['f1Test'], results_gcn_separate_8['f1Test'], results_gcn_separate_9['f1Test'], results_gcn_separate_10['f1Test']],axis=1)

# make lists of the final test f1
final_f1_test_gcn_filtered = [results_gcn_filtered_1['f1Test'].iloc[-1], results_gcn_filtered_2['f1Test'].iloc[-1], results_gcn_filtered_3['f1Test'].iloc[-1], results_gcn_filtered_4['f1Test'].iloc[-1], results_gcn_filtered_5['f1Test'].iloc[-1],results_gcn_filtered_6['f1Test'].iloc[-1], results_gcn_filtered_7['f1Test'].iloc[-1], results_gcn_filtered_8['f1Test'].iloc[-1], results_gcn_filtered_9['f1Test'].iloc[-1], results_gcn_filtered_10['f1Test'].iloc[-1]]
final_f1_test_gcn_alltoone = [results_gcn_alltoone_1['f1Test'].iloc[-1], results_gcn_alltoone_2['f1Test'].iloc[-1], results_gcn_alltoone_3['f1Test'].iloc[-1], results_gcn_alltoone_4['f1Test'].iloc[-1], results_gcn_alltoone_5['f1Test'].iloc[-1],results_gcn_alltoone_6['f1Test'].iloc[-1], results_gcn_alltoone_7['f1Test'].iloc[-1], results_gcn_alltoone_8['f1Test'].iloc[-1], results_gcn_alltoone_9['f1Test'].iloc[-1], results_gcn_alltoone_10['f1Test'].iloc[-1]]
final_f1_test_gcn_collapsed = [results_gcn_collapsed_1['f1Test'].iloc[-1], results_gcn_collapsed_2['f1Test'].iloc[-1], results_gcn_collapsed_3['f1Test'].iloc[-1], results_gcn_collapsed_4['f1Test'].iloc[-1], results_gcn_collapsed_5['f1Test'].iloc[-1],results_gcn_collapsed_6['f1Test'].iloc[-1], results_gcn_collapsed_7['f1Test'].iloc[-1], results_gcn_collapsed_8['f1Test'].iloc[-1], results_gcn_collapsed_9['f1Test'].iloc[-1], results_gcn_collapsed_10['f1Test'].iloc[-1]]
final_f1_test_gcn_separate = [results_gcn_separate_1['f1Test'].iloc[-1], results_gcn_separate_2['f1Test'].iloc[-1], results_gcn_separate_3['f1Test'].iloc[-1], results_gcn_separate_4['f1Test'].iloc[-1], results_gcn_separate_5['f1Test'].iloc[-1],results_gcn_separate_6['f1Test'].iloc[-1], results_gcn_separate_7['f1Test'].iloc[-1], results_gcn_separate_8['f1Test'].iloc[-1], results_gcn_separate_9['f1Test'].iloc[-1], results_gcn_separate_10['f1Test'].iloc[-1]]

# %%
# accuracy:
mean_acc_gcn_filtered = accuracy_test_gcn_filtered.mean(axis=1)
mean_acc_gcn_alltoone = accuracy_test_gcn_alltoone.mean(axis=1)
mean_acc_gcn_collapsed = accuracy_test_gcn_collapsed.mean(axis=1)
mean_acc_gcn_separate = accuracy_test_gcn_separate.mean(axis=1)

std_acc_gcn_filtered = accuracy_test_gcn_filtered.std(axis=1)
std_acc_gcn_alltoone = accuracy_test_gcn_alltoone.std(axis=1)
std_acc_gcn_collapsed = accuracy_test_gcn_collapsed.std(axis=1)
std_acc_gcn_separate = accuracy_test_gcn_separate.std(axis=1)

# f1:
mean_f1_gcn_filtered = f1_test_gcn_filtered.mean(axis=1)
mean_f1_gcn_alltoone = f1_test_gcn_alltoone.mean(axis=1)
mean_f1_gcn_collapsed = f1_test_gcn_collapsed.mean(axis=1)
mean_f1_gcn_separate = f1_test_gcn_separate.mean(axis=1)

std_f1_gcn_filtered = f1_test_gcn_filtered.std(axis=1)
std_f1_gcn_alltoone = f1_test_gcn_alltoone.std(axis=1)
std_f1_gcn_collapsed = f1_test_gcn_collapsed.std(axis=1)
std_f1_gcn_separate = f1_test_gcn_separate.std(axis=1)

# %% [markdown]
# ### RGCN:

# %%
# combine the test accuracies
accuracy_test_rgcn_filtered = pd.concat([results_rgcn_filtered_1['AccTest'], results_rgcn_filtered_2['AccTest'], results_rgcn_filtered_3['AccTest'], results_rgcn_filtered_4['AccTest'], results_rgcn_filtered_5['AccTest'],results_rgcn_filtered_6['AccTest'], results_rgcn_filtered_7['AccTest'], results_rgcn_filtered_8['AccTest'], results_rgcn_filtered_9['AccTest'], results_rgcn_filtered_10['AccTest']],axis=1)
accuracy_test_rgcn_alltoone = pd.concat([results_rgcn_alltoone_1['AccTest'], results_rgcn_alltoone_2['AccTest'], results_rgcn_alltoone_3['AccTest'], results_rgcn_alltoone_4['AccTest'], results_rgcn_alltoone_5['AccTest'],results_rgcn_alltoone_6['AccTest'], results_rgcn_alltoone_7['AccTest'], results_rgcn_alltoone_8['AccTest'], results_rgcn_alltoone_9['AccTest'], results_rgcn_alltoone_10['AccTest']],axis=1)
accuracy_test_rgcn_collapsed = pd.concat([results_rgcn_collapsed_1['AccTest'], results_rgcn_collapsed_2['AccTest'], results_rgcn_collapsed_3['AccTest'], results_rgcn_collapsed_4['AccTest'], results_rgcn_collapsed_5['AccTest'],results_rgcn_collapsed_6['AccTest'], results_rgcn_collapsed_7['AccTest'], results_rgcn_collapsed_8['AccTest'], results_rgcn_collapsed_9['AccTest'], results_rgcn_collapsed_10['AccTest']],axis=1)
accuracy_test_rgcn_separate = pd.concat([results_rgcn_separate_1['AccTest'], results_rgcn_separate_2['AccTest'], results_rgcn_separate_3['AccTest'], results_rgcn_separate_4['AccTest'], results_rgcn_separate_5['AccTest'],results_rgcn_separate_6['AccTest'], results_rgcn_separate_7['AccTest'], results_rgcn_separate_8['AccTest'], results_rgcn_separate_9['AccTest'], results_rgcn_separate_10['AccTest']],axis=1)

# make lists of the final test accuracies
final_accuracy_test_rgcn_filtered = [results_rgcn_filtered_1['AccTest'].iloc[-1], results_rgcn_filtered_2['AccTest'].iloc[-1], results_rgcn_filtered_3['AccTest'].iloc[-1], results_rgcn_filtered_4['AccTest'].iloc[-1], results_rgcn_filtered_5['AccTest'].iloc[-1],results_rgcn_filtered_6['AccTest'].iloc[-1], results_rgcn_filtered_7['AccTest'].iloc[-1], results_rgcn_filtered_8['AccTest'].iloc[-1], results_rgcn_filtered_9['AccTest'].iloc[-1], results_rgcn_filtered_10['AccTest'].iloc[-1]]
final_accuracy_test_rgcn_alltoone = [results_rgcn_alltoone_1['AccTest'].iloc[-1], results_rgcn_alltoone_2['AccTest'].iloc[-1], results_rgcn_alltoone_3['AccTest'].iloc[-1], results_rgcn_alltoone_4['AccTest'].iloc[-1], results_rgcn_alltoone_5['AccTest'].iloc[-1],results_rgcn_alltoone_6['AccTest'].iloc[-1], results_rgcn_alltoone_7['AccTest'].iloc[-1], results_rgcn_alltoone_8['AccTest'].iloc[-1], results_rgcn_alltoone_9['AccTest'].iloc[-1], results_rgcn_alltoone_10['AccTest'].iloc[-1]]
final_accuracy_test_rgcn_collapsed = [results_rgcn_collapsed_1['AccTest'].iloc[-1], results_rgcn_collapsed_2['AccTest'].iloc[-1], results_rgcn_collapsed_3['AccTest'].iloc[-1], results_rgcn_collapsed_4['AccTest'].iloc[-1], results_rgcn_collapsed_5['AccTest'].iloc[-1],results_rgcn_collapsed_6['AccTest'].iloc[-1], results_rgcn_collapsed_7['AccTest'].iloc[-1], results_rgcn_collapsed_8['AccTest'].iloc[-1], results_rgcn_collapsed_9['AccTest'].iloc[-1], results_rgcn_collapsed_10['AccTest'].iloc[-1]]
final_accuracy_test_rgcn_separate = [results_rgcn_separate_1['AccTest'].iloc[-1], results_rgcn_separate_2['AccTest'].iloc[-1], results_rgcn_separate_3['AccTest'].iloc[-1], results_rgcn_separate_4['AccTest'].iloc[-1], results_rgcn_separate_5['AccTest'].iloc[-1],results_rgcn_separate_6['AccTest'].iloc[-1], results_rgcn_separate_7['AccTest'].iloc[-1], results_rgcn_separate_8['AccTest'].iloc[-1], results_rgcn_separate_9['AccTest'].iloc[-1], results_rgcn_separate_10['AccTest'].iloc[-1]]

# combine the test f1
f1_test_rgcn_filtered = pd.concat([results_rgcn_filtered_1['f1Test'], results_rgcn_filtered_2['f1Test'], results_rgcn_filtered_3['f1Test'], results_rgcn_filtered_4['f1Test'], results_rgcn_filtered_5['f1Test'],results_rgcn_filtered_6['f1Test'], results_rgcn_filtered_7['f1Test'], results_rgcn_filtered_8['f1Test'], results_rgcn_filtered_9['f1Test'], results_rgcn_filtered_10['f1Test']],axis=1)
f1_test_rgcn_alltoone = pd.concat([results_rgcn_alltoone_1['f1Test'], results_rgcn_alltoone_2['f1Test'], results_rgcn_alltoone_3['f1Test'], results_rgcn_alltoone_4['f1Test'], results_rgcn_alltoone_5['f1Test'],results_rgcn_alltoone_6['f1Test'], results_rgcn_alltoone_7['f1Test'], results_rgcn_alltoone_8['f1Test'], results_rgcn_alltoone_9['f1Test'], results_rgcn_alltoone_10['f1Test']],axis=1)
f1_test_rgcn_collapsed = pd.concat([results_rgcn_collapsed_1['f1Test'], results_rgcn_collapsed_2['f1Test'], results_rgcn_collapsed_3['f1Test'], results_rgcn_collapsed_4['f1Test'], results_rgcn_collapsed_5['f1Test'],results_rgcn_collapsed_6['f1Test'], results_rgcn_collapsed_7['f1Test'], results_rgcn_collapsed_8['f1Test'], results_rgcn_collapsed_9['f1Test'], results_rgcn_collapsed_10['f1Test']],axis=1)
f1_test_rgcn_separate = pd.concat([results_rgcn_separate_1['f1Test'], results_rgcn_separate_2['f1Test'], results_rgcn_separate_3['f1Test'], results_rgcn_separate_4['f1Test'], results_rgcn_separate_5['f1Test'],results_rgcn_separate_6['f1Test'], results_rgcn_separate_7['f1Test'], results_rgcn_separate_8['f1Test'], results_rgcn_separate_9['f1Test'], results_rgcn_separate_10['f1Test']],axis=1)

# make lists of the final test f1
final_f1_test_rgcn_filtered = [results_rgcn_filtered_1['f1Test'].iloc[-1], results_rgcn_filtered_2['f1Test'].iloc[-1], results_rgcn_filtered_3['f1Test'].iloc[-1], results_rgcn_filtered_4['f1Test'].iloc[-1], results_rgcn_filtered_5['f1Test'].iloc[-1],results_rgcn_filtered_6['f1Test'].iloc[-1], results_rgcn_filtered_7['f1Test'].iloc[-1], results_rgcn_filtered_8['f1Test'].iloc[-1], results_rgcn_filtered_9['f1Test'].iloc[-1], results_rgcn_filtered_10['f1Test'].iloc[-1]]
final_f1_test_rgcn_alltoone = [results_rgcn_alltoone_1['f1Test'].iloc[-1], results_rgcn_alltoone_2['f1Test'].iloc[-1], results_rgcn_alltoone_3['f1Test'].iloc[-1], results_rgcn_alltoone_4['f1Test'].iloc[-1], results_rgcn_alltoone_5['f1Test'].iloc[-1],results_rgcn_alltoone_6['f1Test'].iloc[-1], results_rgcn_alltoone_7['f1Test'].iloc[-1], results_rgcn_alltoone_8['f1Test'].iloc[-1], results_rgcn_alltoone_9['f1Test'].iloc[-1], results_rgcn_alltoone_10['f1Test'].iloc[-1]]
final_f1_test_rgcn_collapsed = [results_rgcn_collapsed_1['f1Test'].iloc[-1], results_rgcn_collapsed_2['f1Test'].iloc[-1], results_rgcn_collapsed_3['f1Test'].iloc[-1], results_rgcn_collapsed_4['f1Test'].iloc[-1], results_rgcn_collapsed_5['f1Test'].iloc[-1],results_rgcn_collapsed_6['f1Test'].iloc[-1], results_rgcn_collapsed_7['f1Test'].iloc[-1], results_rgcn_collapsed_8['f1Test'].iloc[-1], results_rgcn_collapsed_9['f1Test'].iloc[-1], results_rgcn_collapsed_10['f1Test'].iloc[-1]]
final_f1_test_rgcn_separate = [results_rgcn_separate_1['f1Test'].iloc[-1], results_rgcn_separate_2['f1Test'].iloc[-1], results_rgcn_separate_3['f1Test'].iloc[-1], results_rgcn_separate_4['f1Test'].iloc[-1], results_rgcn_separate_5['f1Test'].iloc[-1],results_rgcn_separate_6['f1Test'].iloc[-1], results_rgcn_separate_7['f1Test'].iloc[-1], results_rgcn_separate_8['f1Test'].iloc[-1], results_rgcn_separate_9['f1Test'].iloc[-1], results_rgcn_separate_10['f1Test'].iloc[-1]]

# %%
# accuracy:
mean_acc_rgcn_filtered = accuracy_test_rgcn_filtered.mean(axis=1)
mean_acc_rgcn_alltoone = accuracy_test_rgcn_alltoone.mean(axis=1)
mean_acc_rgcn_collapsed = accuracy_test_rgcn_collapsed.mean(axis=1)
mean_acc_rgcn_separate = accuracy_test_rgcn_separate.mean(axis=1)

std_acc_rgcn_filtered = accuracy_test_rgcn_filtered.std(axis=1)
std_acc_rgcn_alltoone = accuracy_test_rgcn_alltoone.std(axis=1)
std_acc_rgcn_collapsed = accuracy_test_rgcn_collapsed.std(axis=1)
std_acc_rgcn_separate = accuracy_test_rgcn_separate.std(axis=1)

# f1:
mean_f1_rgcn_filtered = f1_test_rgcn_filtered.mean(axis=1)
mean_f1_rgcn_alltoone = f1_test_rgcn_alltoone.mean(axis=1)
mean_f1_rgcn_collapsed = f1_test_rgcn_collapsed.mean(axis=1)
mean_f1_rgcn_separate = f1_test_rgcn_separate.mean(axis=1)

std_f1_rgcn_filtered = f1_test_rgcn_filtered.std(axis=1)
std_f1_rgcn_alltoone = f1_test_rgcn_alltoone.std(axis=1)
std_f1_rgcn_collapsed = f1_test_rgcn_collapsed.std(axis=1)
std_f1_rgcn_separate = f1_test_rgcn_separate.std(axis=1)

# %% [markdown]
# ### GAT:

# %%
# combine the test accuracies
accuracy_test_gat_filtered = pd.concat([results_gat_filtered_1['AccTest'], results_gat_filtered_2['AccTest'], results_gat_filtered_3['AccTest'], results_gat_filtered_4['AccTest'], results_gat_filtered_5['AccTest'],results_gat_filtered_6['AccTest'], results_gat_filtered_7['AccTest'], results_gat_filtered_8['AccTest'], results_gat_filtered_9['AccTest'], results_gat_filtered_10['AccTest']],axis=1)
accuracy_test_gat_alltoone = pd.concat([results_gat_alltoone_1['AccTest'], results_gat_alltoone_2['AccTest'], results_gat_alltoone_3['AccTest'], results_gat_alltoone_4['AccTest'], results_gat_alltoone_5['AccTest'],results_gat_alltoone_6['AccTest'], results_gat_alltoone_7['AccTest'], results_gat_alltoone_8['AccTest'], results_gat_alltoone_9['AccTest'], results_gat_alltoone_10['AccTest']],axis=1)
accuracy_test_gat_collapsed = pd.concat([results_gat_collapsed_1['AccTest'], results_gat_collapsed_2['AccTest'], results_gat_collapsed_3['AccTest'], results_gat_collapsed_4['AccTest'], results_gat_collapsed_5['AccTest'],results_gat_collapsed_6['AccTest'], results_gat_collapsed_7['AccTest'], results_gat_collapsed_8['AccTest'], results_gat_collapsed_9['AccTest'], results_gat_collapsed_10['AccTest']],axis=1)
accuracy_test_gat_separate = pd.concat([results_gat_separate_1['AccTest'], results_gat_separate_2['AccTest'], results_gat_separate_3['AccTest'], results_gat_separate_4['AccTest'], results_gat_separate_5['AccTest'],results_gat_separate_6['AccTest'], results_gat_separate_7['AccTest'], results_gat_separate_8['AccTest'], results_gat_separate_9['AccTest'], results_gat_separate_10['AccTest']],axis=1)

# make lists of the final test accuracies
final_accuracy_test_gat_filtered = [results_gat_filtered_1['AccTest'].iloc[-1], results_gat_filtered_2['AccTest'].iloc[-1], results_gat_filtered_3['AccTest'].iloc[-1], results_gat_filtered_4['AccTest'].iloc[-1], results_gat_filtered_5['AccTest'].iloc[-1],results_gat_filtered_6['AccTest'].iloc[-1], results_gat_filtered_7['AccTest'].iloc[-1], results_gat_filtered_8['AccTest'].iloc[-1], results_gat_filtered_9['AccTest'].iloc[-1], results_gat_filtered_10['AccTest'].iloc[-1]]
final_accuracy_test_gat_alltoone = [results_gat_alltoone_1['AccTest'].iloc[-1], results_gat_alltoone_2['AccTest'].iloc[-1], results_gat_alltoone_3['AccTest'].iloc[-1], results_gat_alltoone_4['AccTest'].iloc[-1], results_gat_alltoone_5['AccTest'].iloc[-1],results_gat_alltoone_6['AccTest'].iloc[-1], results_gat_alltoone_7['AccTest'].iloc[-1], results_gat_alltoone_8['AccTest'].iloc[-1], results_gat_alltoone_9['AccTest'].iloc[-1], results_gat_alltoone_10['AccTest'].iloc[-1]]
final_accuracy_test_gat_collapsed = [results_gat_collapsed_1['AccTest'].iloc[-1], results_gat_collapsed_2['AccTest'].iloc[-1], results_gat_collapsed_3['AccTest'].iloc[-1], results_gat_collapsed_4['AccTest'].iloc[-1], results_gat_collapsed_5['AccTest'].iloc[-1],results_gat_collapsed_6['AccTest'].iloc[-1], results_gat_collapsed_7['AccTest'].iloc[-1], results_gat_collapsed_8['AccTest'].iloc[-1], results_gat_collapsed_9['AccTest'].iloc[-1], results_gat_collapsed_10['AccTest'].iloc[-1]]
final_accuracy_test_gat_separate = [results_gat_separate_1['AccTest'].iloc[-1], results_gat_separate_2['AccTest'].iloc[-1], results_gat_separate_3['AccTest'].iloc[-1], results_gat_separate_4['AccTest'].iloc[-1], results_gat_separate_5['AccTest'].iloc[-1],results_gat_separate_6['AccTest'].iloc[-1], results_gat_separate_7['AccTest'].iloc[-1], results_gat_separate_8['AccTest'].iloc[-1], results_gat_separate_9['AccTest'].iloc[-1], results_gat_separate_10['AccTest'].iloc[-1]]

# combine the test f1
f1_test_gat_filtered = pd.concat([results_gat_filtered_1['f1Test'], results_gat_filtered_2['f1Test'], results_gat_filtered_3['f1Test'], results_gat_filtered_4['f1Test'], results_gat_filtered_5['f1Test'],results_gat_filtered_6['f1Test'], results_gat_filtered_7['f1Test'], results_gat_filtered_8['f1Test'], results_gat_filtered_9['f1Test'], results_gat_filtered_10['f1Test']],axis=1)
f1_test_gat_alltoone = pd.concat([results_gat_alltoone_1['f1Test'], results_gat_alltoone_2['f1Test'], results_gat_alltoone_3['f1Test'], results_gat_alltoone_4['f1Test'], results_gat_alltoone_5['f1Test'],results_gat_alltoone_6['f1Test'], results_gat_alltoone_7['f1Test'], results_gat_alltoone_8['f1Test'], results_gat_alltoone_9['f1Test'], results_gat_alltoone_10['f1Test']],axis=1)
f1_test_gat_collapsed = pd.concat([results_gat_collapsed_1['f1Test'], results_gat_collapsed_2['f1Test'], results_gat_collapsed_3['f1Test'], results_gat_collapsed_4['f1Test'], results_gat_collapsed_5['f1Test'],results_gat_collapsed_6['f1Test'], results_gat_collapsed_7['f1Test'], results_gat_collapsed_8['f1Test'], results_gat_collapsed_9['f1Test'], results_gat_collapsed_10['f1Test']],axis=1)
f1_test_gat_separate = pd.concat([results_gat_separate_1['f1Test'], results_gat_separate_2['f1Test'], results_gat_separate_3['f1Test'], results_gat_separate_4['f1Test'], results_gat_separate_5['f1Test'],results_gat_separate_6['f1Test'], results_gat_separate_7['f1Test'], results_gat_separate_8['f1Test'], results_gat_separate_9['f1Test'], results_gat_separate_10['f1Test']],axis=1)

# make lists of the final test f1
final_f1_test_gat_filtered = [results_gat_filtered_1['f1Test'].iloc[-1], results_gat_filtered_2['f1Test'].iloc[-1], results_gat_filtered_3['f1Test'].iloc[-1], results_gat_filtered_4['f1Test'].iloc[-1], results_gat_filtered_5['f1Test'].iloc[-1],results_gat_filtered_6['f1Test'].iloc[-1], results_gat_filtered_7['f1Test'].iloc[-1], results_gat_filtered_8['f1Test'].iloc[-1], results_gat_filtered_9['f1Test'].iloc[-1], results_gat_filtered_10['f1Test'].iloc[-1]]
final_f1_test_gat_alltoone = [results_gat_alltoone_1['f1Test'].iloc[-1], results_gat_alltoone_2['f1Test'].iloc[-1], results_gat_alltoone_3['f1Test'].iloc[-1], results_gat_alltoone_4['f1Test'].iloc[-1], results_gat_alltoone_5['f1Test'].iloc[-1],results_gat_alltoone_6['f1Test'].iloc[-1], results_gat_alltoone_7['f1Test'].iloc[-1], results_gat_alltoone_8['f1Test'].iloc[-1], results_gat_alltoone_9['f1Test'].iloc[-1], results_gat_alltoone_10['f1Test'].iloc[-1]]
final_f1_test_gat_collapsed = [results_gat_collapsed_1['f1Test'].iloc[-1], results_gat_collapsed_2['f1Test'].iloc[-1], results_gat_collapsed_3['f1Test'].iloc[-1], results_gat_collapsed_4['f1Test'].iloc[-1], results_gat_collapsed_5['f1Test'].iloc[-1],results_gat_collapsed_6['f1Test'].iloc[-1], results_gat_collapsed_7['f1Test'].iloc[-1], results_gat_collapsed_8['f1Test'].iloc[-1], results_gat_collapsed_9['f1Test'].iloc[-1], results_gat_collapsed_10['f1Test'].iloc[-1]]
final_f1_test_gat_separate = [results_gat_separate_1['f1Test'].iloc[-1], results_gat_separate_2['f1Test'].iloc[-1], results_gat_separate_3['f1Test'].iloc[-1], results_gat_separate_4['f1Test'].iloc[-1], results_gat_separate_5['f1Test'].iloc[-1],results_gat_separate_6['f1Test'].iloc[-1], results_gat_separate_7['f1Test'].iloc[-1], results_gat_separate_8['f1Test'].iloc[-1], results_gat_separate_9['f1Test'].iloc[-1], results_gat_separate_10['f1Test'].iloc[-1]]

# %%
# accuracy:
mean_acc_gat_filtered = accuracy_test_gat_filtered.mean(axis=1)
mean_acc_gat_alltoone = accuracy_test_gat_alltoone.mean(axis=1)
mean_acc_gat_collapsed = accuracy_test_gat_collapsed.mean(axis=1)
mean_acc_gat_separate = accuracy_test_gat_separate.mean(axis=1)

std_acc_gat_filtered = accuracy_test_gat_filtered.std(axis=1)
std_acc_gat_alltoone = accuracy_test_gat_alltoone.std(axis=1)
std_acc_gat_collapsed = accuracy_test_gat_collapsed.std(axis=1)
std_acc_gat_separate = accuracy_test_gat_separate.std(axis=1)

# f1:
mean_f1_gat_filtered = f1_test_gat_filtered.mean(axis=1)
mean_f1_gat_alltoone = f1_test_gat_alltoone.mean(axis=1)
mean_f1_gat_collapsed = f1_test_gat_collapsed.mean(axis=1)
mean_f1_gat_separate = f1_test_gat_separate.mean(axis=1)

std_f1_gat_filtered = f1_test_gat_filtered.std(axis=1)
std_f1_gat_alltoone = f1_test_gat_alltoone.std(axis=1)
std_f1_gat_collapsed = f1_test_gat_collapsed.std(axis=1)
std_f1_gat_separate = f1_test_gat_separate.std(axis=1)

# %% [markdown]
# ## Plot the data:

# %% [markdown]
# ### GAE:

# %% [markdown]
# ### GCN:

# %%
# draw the lines for the means
plt.plot(mean_acc_gcn_filtered.index.values, mean_acc_gcn_filtered, 'y-', label='Filtered')
plt.plot(mean_acc_gcn_alltoone.index.values, mean_acc_gcn_alltoone, 'r-', label='All-to-one')
plt.plot(mean_acc_gcn_collapsed.index.values, mean_acc_gcn_collapsed, 'b-', label='Collapsed')
plt.plot(mean_acc_gcn_separate.index.values, mean_acc_gcn_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_acc_gcn_filtered.index.values, mean_acc_gcn_filtered - std_acc_gcn_filtered, mean_acc_gcn_separate + std_acc_gcn_filtered, color='y', alpha=0.25)
plt.fill_between(std_acc_gcn_alltoone.index.values, mean_acc_gcn_alltoone - std_acc_gcn_alltoone, mean_acc_gcn_alltoone + std_acc_gcn_alltoone, color='r', alpha=0.25)
plt.fill_between(std_acc_gcn_collapsed.index.values, mean_acc_gcn_collapsed - std_acc_gcn_collapsed, mean_acc_gcn_collapsed + std_acc_gcn_collapsed, color='b', alpha=0.25)
plt.fill_between(std_acc_gcn_separate.index.values, mean_acc_gcn_separate - std_acc_gcn_separate, mean_acc_gcn_separate + std_acc_gcn_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test Accuracy of GCN for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/gcn_test_acc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_f1_gcn_filtered.index.values, mean_f1_gcn_filtered, 'y-', label='Filtered')
plt.plot(mean_f1_gcn_alltoone.index.values, mean_f1_gcn_alltoone, 'r-', label='All-to-one')
plt.plot(mean_f1_gcn_collapsed.index.values, mean_f1_gcn_collapsed, 'b-', label='Collapsed')
plt.plot(mean_f1_gcn_separate.index.values, mean_f1_gcn_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_f1_gcn_filtered.index.values, mean_f1_gcn_filtered - std_f1_gcn_filtered, mean_f1_gcn_separate + std_f1_gcn_filtered, color='y', alpha=0.25)
plt.fill_between(std_f1_gcn_alltoone.index.values, mean_f1_gcn_alltoone - std_f1_gcn_alltoone, mean_f1_gcn_alltoone + std_f1_gcn_alltoone, color='r', alpha=0.25)
plt.fill_between(std_f1_gcn_collapsed.index.values, mean_f1_gcn_collapsed - std_f1_gcn_collapsed, mean_f1_gcn_collapsed + std_f1_gcn_collapsed, color='b', alpha=0.25)
plt.fill_between(std_f1_gcn_separate.index.values, mean_f1_gcn_separate - std_f1_gcn_separate, mean_f1_gcn_separate + std_f1_gcn_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test f1 of GCN for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test f1', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/gcn_test_f1.png', dpi=300)

plt.show()

# %% [markdown]
# ### RGCN:

# %%
# draw the lines for the means
plt.plot(mean_acc_rgcn_filtered.index.values, mean_acc_rgcn_filtered, 'y-', label='Filtered')
plt.plot(mean_acc_rgcn_alltoone.index.values, mean_acc_rgcn_alltoone, 'r-', label='All-to-one')
plt.plot(mean_acc_rgcn_collapsed.index.values, mean_acc_rgcn_collapsed, 'b-', label='Collapsed')
plt.plot(mean_acc_rgcn_separate.index.values, mean_acc_rgcn_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_acc_rgcn_filtered.index.values, mean_acc_rgcn_filtered - std_acc_rgcn_filtered, mean_acc_rgcn_separate + std_acc_rgcn_filtered, color='y', alpha=0.25)
plt.fill_between(std_acc_rgcn_alltoone.index.values, mean_acc_rgcn_alltoone - std_acc_rgcn_alltoone, mean_acc_rgcn_alltoone + std_acc_rgcn_alltoone, color='r', alpha=0.25)
plt.fill_between(std_acc_rgcn_collapsed.index.values, mean_acc_rgcn_collapsed - std_acc_rgcn_collapsed, mean_acc_rgcn_collapsed + std_acc_rgcn_collapsed, color='b', alpha=0.25)
plt.fill_between(std_acc_rgcn_separate.index.values, mean_acc_rgcn_separate - std_acc_rgcn_separate, mean_acc_rgcn_separate + std_acc_rgcn_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test Accuracy of RGCN for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/rgcn_test_acc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_f1_rgcn_filtered.index.values, mean_f1_rgcn_filtered, 'y-', label='Filtered')
plt.plot(mean_f1_rgcn_alltoone.index.values, mean_f1_rgcn_alltoone, 'r-', label='All-to-one')
plt.plot(mean_f1_rgcn_collapsed.index.values, mean_f1_rgcn_collapsed, 'b-', label='Collapsed')
plt.plot(mean_f1_rgcn_separate.index.values, mean_f1_rgcn_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_f1_rgcn_filtered.index.values, mean_f1_rgcn_filtered - std_f1_rgcn_filtered, mean_f1_rgcn_separate + std_f1_rgcn_filtered, color='y', alpha=0.25)
plt.fill_between(std_f1_rgcn_alltoone.index.values, mean_f1_rgcn_alltoone - std_f1_rgcn_alltoone, mean_f1_rgcn_alltoone + std_f1_rgcn_alltoone, color='r', alpha=0.25)
plt.fill_between(std_f1_rgcn_collapsed.index.values, mean_f1_rgcn_collapsed - std_f1_rgcn_collapsed, mean_f1_rgcn_collapsed + std_f1_rgcn_collapsed, color='b', alpha=0.25)
plt.fill_between(std_f1_rgcn_separate.index.values, mean_f1_rgcn_separate - std_f1_rgcn_separate, mean_f1_rgcn_separate + std_f1_rgcn_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test f1 of RGCN for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test f1', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/rgcn_test_f1.png', dpi=300)

plt.show()

# %% [markdown]
# ### GAT:

# %%
# draw the lines for the means
plt.plot(mean_acc_gat_filtered.index.values, mean_acc_gat_filtered, 'y-', label='Filtered')
plt.plot(mean_acc_gat_alltoone.index.values, mean_acc_gat_alltoone, 'r-', label='All-to-one')
plt.plot(mean_acc_gat_collapsed.index.values, mean_acc_gat_collapsed, 'b-', label='Collapsed')
plt.plot(mean_acc_gat_separate.index.values, mean_acc_gat_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_acc_gat_filtered.index.values, mean_acc_gat_filtered - std_acc_gat_filtered, mean_acc_gat_separate + std_acc_gat_filtered, color='y', alpha=0.25)
plt.fill_between(std_acc_gat_alltoone.index.values, mean_acc_gat_alltoone - std_acc_gat_alltoone, mean_acc_gat_alltoone + std_acc_gat_alltoone, color='r', alpha=0.25)
plt.fill_between(std_acc_gat_collapsed.index.values, mean_acc_gat_collapsed - std_acc_gat_collapsed, mean_acc_gat_collapsed + std_acc_gat_collapsed, color='b', alpha=0.25)
plt.fill_between(std_acc_gat_separate.index.values, mean_acc_gat_separate - std_acc_gat_separate, mean_acc_gat_separate + std_acc_gat_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test Accuracy of GAT for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test Accuracy', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/gat_test_acc.png', dpi=300)

plt.show()

# %%
# draw the lines for the means
plt.plot(mean_f1_gat_filtered.index.values, mean_f1_gat_filtered, 'y-', label='Filtered')
plt.plot(mean_f1_gat_alltoone.index.values, mean_f1_gat_alltoone, 'r-', label='All-to-one')
plt.plot(mean_f1_gat_collapsed.index.values, mean_f1_gat_collapsed, 'b-', label='Collapsed')
plt.plot(mean_f1_gat_separate.index.values, mean_f1_gat_separate, 'g-', label='Separate')

# fill between the standard deviations
plt.fill_between(std_f1_gat_filtered.index.values, mean_f1_gat_filtered - std_f1_gat_filtered, mean_f1_gat_separate + std_f1_gat_filtered, color='y', alpha=0.25)
plt.fill_between(std_f1_gat_alltoone.index.values, mean_f1_gat_alltoone - std_f1_gat_alltoone, mean_f1_gat_alltoone + std_f1_gat_alltoone, color='r', alpha=0.25)
plt.fill_between(std_f1_gat_collapsed.index.values, mean_f1_gat_collapsed - std_f1_gat_collapsed, mean_f1_gat_collapsed + std_f1_gat_collapsed, color='b', alpha=0.25)
plt.fill_between(std_f1_gat_separate.index.values, mean_f1_gat_separate - std_f1_gat_separate, mean_f1_gat_separate + std_f1_gat_separate, color='g', alpha=0.25)

plt.legend(loc="lower right", fontsize=21)
# plt.title("Test f1 of GAT for AIFB+ Dataset with Different Literal Mappings", fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize = 18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Test f1', fontsize=20)

# increase size of figure
figure = plt.gcf()
figure.set_size_inches(13, 9)

# save the figure
figure.savefig('../plots/experiment_data_analysis/aifb/gat_test_f1.png', dpi=300)

plt.show()

# %% [markdown]
# ## Perform statistical tests:

# %% [markdown]
# ### GAE:

# %% [markdown]
# ### GCN:

# %% [markdown]
# ### RGCN:

# %% [markdown]
# ### GAT:
